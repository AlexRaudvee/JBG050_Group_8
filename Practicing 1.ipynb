# %% [markdown]
# # This code is to show the different asnwers of a specific question for the different boroughs

# %%
import pandas as pd
import os

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_19_20.csv'

#Name of the columns we want to extract values from
columname = 'NQ135BD'
borough_column = 'BOROUGHNEIGHBOURHOODCODED' #This should be changed to Borough if you look in the file of 20-21

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Group the DataFrame by the "Borough" column
grouped_df = df.groupby(borough_column)

#Print the occurrences of values for each borough
for borough, group_df in grouped_df:
    print(f"\nBorough: {borough}")
    value_counts = group_df[column_name].value_counts()
    print(value_counts)
# Out:
# Borough: Barking and Dagenham - Barking
# NQ135BD
# Strongly agree                67
# Tend to agree                 61
# Tend to disagree               9
# Neither agree nor disagree     9
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Barking and Dagenham - Dagenham
# NQ135BD
# Tend to agree                 55
# Strongly agree                46
# Neither agree nor disagree    11
# Tend to disagree               6
# Strongly disagree              5
# Name: count, dtype: int64
#
# Borough: Barking and Dagenham - Whalebone
# NQ135BD
# Strongly agree                60
# Tend to agree                 42
# Neither agree nor disagree     8
# Tend to disagree               5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Barnet - Barnet
# NQ135BD
# Tend to agree                 50
# Strongly agree                29
# Neither agree nor disagree     8
# Tend to disagree               3
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Barnet - Colindale
# NQ135BD
# Strongly agree                48
# Tend to agree                 36
# Neither agree nor disagree     3
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Barnet - Golders Green
# NQ135BD
# Strongly agree                45
# Tend to agree                 30
# Tend to disagree               3
# Neither agree nor disagree     2
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Barnet - Whetstone
# NQ135BD
# Tend to agree                 52
# Strongly agree                42
# Neither agree nor disagree     8
# Tend to disagree               5
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Bexley - Central
# NQ135BD
# Tend to agree                 57
# Strongly agree                42
# Neither agree nor disagree     6
# Tend to disagree               6
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Bexley - North
# NQ135BD
# Strongly agree                63
# Tend to agree                 52
# Neither agree nor disagree    16
# Tend to disagree               6
# Name: count, dtype: int64
#
# Borough: Bexley - South
# NQ135BD
# Tend to agree                 64
# Strongly agree                51
# Neither agree nor disagree    11
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Brent - Harlsden
# NQ135BD
# Tend to agree                 52
# Strongly agree                47
# Neither agree nor disagree    11
# Tend to disagree               8
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Brent - Kilburn
# NQ135BD
# Strongly agree                67
# Tend to agree                 49
# Tend to disagree               4
# Neither agree nor disagree     3
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Brent - Wembley
# NQ135BD
# Strongly agree                77
# Tend to agree                 53
# Neither agree nor disagree     8
# Tend to disagree               3
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Bromley - North-East
# NQ135BD
# Tend to agree                 41
# Strongly agree                32
# Neither agree nor disagree    10
# Tend to disagree               3
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Bromley - North-West
# NQ135BD
# Tend to agree                 51
# Strongly agree                32
# Neither agree nor disagree     9
# Strongly disagree              3
# Tend to disagree               3
# Name: count, dtype: int64
#
# Borough: Bromley - South-East
# NQ135BD
# Tend to agree                 57
# Strongly agree                50
# Neither agree nor disagree     7
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Bromley - South-West
# NQ135BD
# Strongly agree                46
# Tend to agree                 31
# Neither agree nor disagree     4
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Camden - Central
# NQ135BD
# Tend to agree                 69
# Strongly agree                37
# Neither agree nor disagree    15
# Tend to disagree              12
# Strongly disagree              6
# Name: count, dtype: int64
#
# Borough: Camden - North
# NQ135BD
# Tend to agree                 81
# Strongly agree                31
# Neither agree nor disagree    16
# Tend to disagree               8
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Camden - South
# NQ135BD
# Tend to agree                 61
# Strongly agree                26
# Neither agree nor disagree    12
# Tend to disagree               8
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Croydon - Central
# NQ135BD
# Tend to agree                 40
# Strongly agree                29
# Tend to disagree               9
# Neither agree nor disagree     7
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Croydon - North-East
# NQ135BD
# Strongly agree                37
# Tend to agree                 34
# Neither agree nor disagree     8
# Tend to disagree               5
# Name: count, dtype: int64
#
# Borough: Croydon - North-West
# NQ135BD
# Tend to agree                 39
# Strongly agree                26
# Neither agree nor disagree    10
# Tend to disagree               7
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Croydon - South-East
# NQ135BD
# Tend to agree                 32
# Strongly agree                25
# Neither agree nor disagree     4
# Tend to disagree               4
# Name: count, dtype: int64
#
# Borough: Croydon - South-West
# NQ135BD
# Tend to agree                 39
# Strongly agree                27
# Tend to disagree               2
# Neither agree nor disagree     2
# Name: count, dtype: int64
#
# Borough: Ealing - Acton
# NQ135BD
# Tend to agree                 50
# Strongly agree                36
# Tend to disagree               6
# Neither agree nor disagree     4
# Name: count, dtype: int64
#
# Borough: Ealing - Ealing
# NQ135BD
# Tend to agree                 52
# Strongly agree                40
# Neither agree nor disagree     5
# Tend to disagree               2
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Ealing - Greenford/Northolt
# NQ135BD
# Strongly agree                51
# Tend to agree                 38
# Tend to disagree               8
# Neither agree nor disagree     5
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Ealing - Southall
# NQ135BD
# Tend to agree                 35
# Strongly agree                29
# Tend to disagree               6
# Neither agree nor disagree     5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Enfield - Edmonton & South
# NQ135BD
# Tend to agree                 42
# Strongly agree                32
# Neither agree nor disagree    16
# Tend to disagree               9
# Strongly disagree              9
# Name: count, dtype: int64
#
# Borough: Enfield - Enfield & North
# NQ135BD
# Tend to agree                 62
# Strongly agree                41
# Neither agree nor disagree    16
# Tend to disagree              12
# Strongly disagree              5
# Name: count, dtype: int64
#
# Borough: Enfield - Southgate & West
# NQ135BD
# Tend to agree                 71
# Strongly agree                37
# Neither agree nor disagree    20
# Tend to disagree               5
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Greenwich - Eltham
# NQ135BD
# Tend to agree                 62
# Strongly agree                37
# Neither agree nor disagree    10
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Greenwich - Greenwich
# NQ135BD
# Tend to agree                 61
# Strongly agree                41
# Neither agree nor disagree    16
# Tend to disagree               5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Greenwich - Plumstead
# NQ135BD
# Tend to agree                 68
# Strongly agree                45
# Neither agree nor disagree    26
# Tend to disagree               4
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Hackney - Hackney North-East
# NQ135BD
# Tend to agree                 57
# Strongly agree                20
# Neither agree nor disagree    17
# Tend to disagree              10
# Strongly disagree              6
# Name: count, dtype: int64
#
# Borough: Hackney - Homerton
# NQ135BD
# Tend to agree                 53
# Strongly agree                10
# Neither agree nor disagree     9
# Tend to disagree               8
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Hackney - Shoreditch
# NQ135BD
# Tend to agree                 57
# Neither agree nor disagree    22
# Strongly agree                 9
# Tend to disagree               7
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Hackney - Stoke Newington
# NQ135BD
# Tend to agree                 49
# Strongly agree                17
# Neither agree nor disagree     9
# Tend to disagree               6
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Hammersmith and Fulham - North Hammersmith
# NQ135BD
# Strongly agree                73
# Tend to agree                 67
# Neither agree nor disagree    15
# Tend to disagree               9
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Hammersmith and Fulham - South Fulham
# NQ135BD
# Tend to agree                 119
# Strongly agree                 71
# Neither agree nor disagree     21
# Tend to disagree                9
# Strongly disagree               3
# Name: count, dtype: int64
#
# Borough: Haringey - East
# NQ135BD
# Tend to agree                 67
# Strongly agree                24
# Neither agree nor disagree    15
# Strongly disagree             12
# Tend to disagree               7
# Name: count, dtype: int64
#
# Borough: Haringey - North
# NQ135BD
# Tend to agree                 37
# Strongly agree                28
# Neither agree nor disagree    14
# Tend to disagree               8
# Strongly disagree              7
# Name: count, dtype: int64
#
# Borough: Haringey - West
# NQ135BD
# Tend to agree                 94
# Strongly agree                52
# Neither agree nor disagree    11
# Tend to disagree               9
# Strongly disagree              7
# Name: count, dtype: int64
#
# Borough: Harrow - Central
# NQ135BD
# Tend to agree                 40
# Strongly agree                40
# Neither agree nor disagree    12
# Tend to disagree               4
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Harrow - East
# NQ135BD
# Strongly agree                67
# Tend to agree                 54
# Neither agree nor disagree     8
# Tend to disagree               4
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Harrow - West
# NQ135BD
# Tend to agree                 66
# Strongly agree                61
# Neither agree nor disagree    16
# Strongly disagree              5
# Tend to disagree               4
# Name: count, dtype: int64
#
# Borough: Havering - Central
# NQ135BD
# Tend to agree                 54
# Strongly agree                50
# Neither agree nor disagree     7
# Tend to disagree               3
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Havering - North
# NQ135BD
# Strongly agree                82
# Tend to agree                 37
# Tend to disagree               8
# Neither agree nor disagree     5
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Havering - South
# NQ135BD
# Strongly agree                54
# Tend to agree                 43
# Neither agree nor disagree    16
# Tend to disagree               4
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Hillingdon - Hayes
# NQ135BD
# Tend to agree                 47
# Strongly agree                39
# Neither agree nor disagree     8
# Strongly disagree              2
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Hillingdon - North
# NQ135BD
# Tend to agree                 69
# Strongly agree                43
# Neither agree nor disagree    18
# Tend to disagree               4
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Hillingdon - Uxbridge
# NQ135BD
# Tend to agree                 32
# Strongly agree                31
# Neither agree nor disagree     9
# Tend to disagree               4
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Hillingdon - West Drayton
# NQ135BD
# Tend to agree                 32
# Strongly agree                29
# Neither agree nor disagree     6
# Strongly disagree              4
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Hounslow - Chiswick
# NQ135BD
# Tend to agree                 47
# Strongly agree                38
# Neither agree nor disagree     8
# Tend to disagree               3
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Hounslow - Feltham
# NQ135BD
# Tend to agree                 49
# Strongly agree                34
# Neither agree nor disagree     7
# Tend to disagree               4
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Hounslow - Heston
# NQ135BD
# Strongly agree                44
# Tend to agree                 36
# Neither agree nor disagree     8
# Strongly disagree              2
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Hounslow - Hounslow
# NQ135BD
# Strongly agree                45
# Tend to agree                 42
# Neither agree nor disagree     7
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Islington - East
# NQ135BD
# Tend to agree                 63
# Strongly agree                16
# Neither agree nor disagree    11
# Strongly disagree              8
# Tend to disagree               7
# Name: count, dtype: int64
#
# Borough: Islington - North
# NQ135BD
# Tend to agree                 54
# Neither agree nor disagree    12
# Strongly agree                10
# Tend to disagree               8
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Islington - South
# NQ135BD
# Tend to agree                 53
# Strongly agree                23
# Neither agree nor disagree     9
# Tend to disagree               5
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Islington - West
# NQ135BD
# Tend to agree                 67
# Strongly agree                10
# Neither agree nor disagree     9
# Tend to disagree               8
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Kensington and Chelsea - Chelsea
# NQ135BD
# Strongly agree                70
# Tend to agree                 45
# Tend to disagree               6
# Neither agree nor disagree     4
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Kensington and Chelsea - Kensington
# NQ135BD
# Strongly agree                86
# Tend to agree                 39
# Neither agree nor disagree    12
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Kensington and Chelsea - Notting Hill
# NQ135BD
# Strongly agree                59
# Tend to agree                 44
# Tend to disagree               7
# Strongly disagree              6
# Neither agree nor disagree     5
# Name: count, dtype: int64
#
# Borough: Kingston upon Thames - North
# NQ135BD
# Tend to agree                 140
# Strongly agree                 50
# Neither agree nor disagree     25
# Tend to disagree                8
# Strongly disagree               2
# Name: count, dtype: int64
#
# Borough: Kingston upon Thames - South
# NQ135BD
# Tend to agree                 111
# Strongly agree                 34
# Neither agree nor disagree      9
# Tend to disagree                1
# Name: count, dtype: int64
#
# Borough: Lambeth - Central
# NQ135BD
# Tend to agree                 45
# Strongly agree                36
# Neither agree nor disagree    25
# Tend to disagree              13
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Lambeth - North
# NQ135BD
# Tend to agree                 53
# Strongly agree                48
# Neither agree nor disagree    11
# Tend to disagree              10
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Lambeth - South
# NQ135BD
# Tend to agree                 58
# Strongly agree                51
# Neither agree nor disagree     8
# Tend to disagree               8
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Lewisham - Central
# NQ135BD
# Strongly agree                56
# Tend to agree                 43
# Neither agree nor disagree     9
# Tend to disagree               6
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Lewisham - North
# NQ135BD
# Tend to agree                 53
# Strongly agree                51
# Neither agree nor disagree    20
# Tend to disagree               5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Lewisham - South
# NQ135BD
# Strongly agree                47
# Tend to agree                 46
# Neither agree nor disagree    23
# Tend to disagree               7
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Merton - Mitcham
# NQ135BD
# Tend to agree                 83
# Strongly agree                28
# Neither agree nor disagree    12
# Tend to disagree               6
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Merton - Morden
# NQ135BD
# Tend to agree                 58
# Strongly agree                36
# Neither agree nor disagree    18
# Tend to disagree               7
# Name: count, dtype: int64
#
# Borough: Merton - Wimbledon
# NQ135BD
# Tend to agree                 89
# Strongly agree                37
# Tend to disagree               3
# Neither agree nor disagree     2
# Name: count, dtype: int64
#
# Borough: Newham - Central
# NQ135BD
# Strongly agree                51
# Tend to agree                 33
# Neither agree nor disagree    12
# Tend to disagree               3
# Name: count, dtype: int64
#
# Borough: Newham - East
# NQ135BD
# Strongly agree                44
# Tend to agree                 26
# Neither agree nor disagree     6
# Strongly disagree              5
# Tend to disagree               5
# Name: count, dtype: int64
#
# Borough: Newham - South
# NQ135BD
# Strongly agree                46
# Tend to agree                 30
# Tend to disagree               9
# Neither agree nor disagree     7
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Newham - West
# NQ135BD
# Strongly agree                39
# Tend to agree                 36
# Neither agree nor disagree    11
# Tend to disagree               8
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Redbridge - Central
# NQ135BD
# Strongly agree                66
# Tend to agree                 37
# Neither agree nor disagree    11
# Strongly disagree              4
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Redbridge - South
# NQ135BD
# Tend to agree                 55
# Strongly agree                24
# Neither agree nor disagree     7
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Redbridge - West
# NQ135BD
# Strongly agree                84
# Tend to agree                 63
# Neither agree nor disagree    15
# Tend to disagree               8
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Richmond upon Thames - Richmond
# NQ135BD
# Tend to agree                 92
# Strongly agree                35
# Neither agree nor disagree    18
# Tend to disagree               3
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Richmond upon Thames - Teddington
# NQ135BD
# Tend to agree                 46
# Strongly agree                34
# Neither agree nor disagree     9
# Tend to disagree               2
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Richmond upon Thames - Twickenham
# NQ135BD
# Tend to agree                 83
# Strongly agree                30
# Neither agree nor disagree    19
# Tend to disagree               4
# Strongly disagree              3
# Name: count, dtype: int64
#
# Borough: Southwark - North-East
# NQ135BD
# Strongly agree                50
# Tend to agree                 34
# Neither agree nor disagree     6
# Tend to disagree               2
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Southwark - North-West
# NQ135BD
# Strongly agree                55
# Tend to agree                 16
# Neither agree nor disagree     9
# Tend to disagree               4
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Southwark - South-East
# NQ135BD
# Strongly agree                43
# Tend to agree                 33
# Neither agree nor disagree    13
# Tend to disagree               7
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Southwark - South-West
# NQ135BD
# Strongly agree                43
# Tend to agree                 33
# Neither agree nor disagree     8
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Sutton - East
# NQ135BD
# Tend to agree                 69
# Strongly agree                31
# Neither agree nor disagree    15
# Tend to disagree               4
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Sutton - North
# NQ135BD
# Tend to agree                 62
# Strongly agree                58
# Neither agree nor disagree    16
# Tend to disagree               6
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Sutton - West
# NQ135BD
# Tend to agree                 79
# Strongly agree                28
# Neither agree nor disagree     7
# Tend to disagree               4
# Name: count, dtype: int64
#
# Borough: Tower Hamlets - Bow and Mile End
# NQ135BD
# Strongly agree                41
# Tend to agree                 38
# Neither agree nor disagree    12
# Tend to disagree               4
# Name: count, dtype: int64
#
# Borough: Tower Hamlets - Bricklane & Globe
# NQ135BD
# Strongly agree                54
# Tend to agree                 32
# Neither agree nor disagree    11
# Tend to disagree               2
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Tower Hamlets - Poplar Isle of Dogs
# NQ135BD
# Strongly agree                37
# Tend to agree                 36
# Neither agree nor disagree     7
# Tend to disagree               5
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Tower Hamlets - Stepney & Wapping
# NQ135BD
# Strongly agree                39
# Tend to agree                 26
# Neither agree nor disagree     7
# Tend to disagree               5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Waltham Forest - Central
# NQ135BD
# Tend to agree                 70
# Strongly agree                34
# Neither agree nor disagree    15
# Tend to disagree               6
# Strongly disagree              5
# Name: count, dtype: int64
#
# Borough: Waltham Forest - North
# NQ135BD
# Strongly agree                45
# Tend to agree                 42
# Neither agree nor disagree    19
# Tend to disagree              10
# Strongly disagree              5
# Name: count, dtype: int64
#
# Borough: Waltham Forest - South
# NQ135BD
# Tend to agree                 63
# Strongly agree                50
# Neither agree nor disagree    14
# Strongly disagree              5
# Tend to disagree               4
# Name: count, dtype: int64
#
# Borough: Wandsworth - Battersea
# NQ135BD
# Tend to agree                 58
# Strongly agree                53
# Neither agree nor disagree    13
# Strongly disagree              4
# Tend to disagree               3
# Name: count, dtype: int64
#
# Borough: Wandsworth - Putney
# NQ135BD
# Tend to agree                 65
# Strongly agree                45
# Neither agree nor disagree    21
# Tend to disagree               5
# Strongly disagree              4
# Name: count, dtype: int64
#
# Borough: Wandsworth - Tooting
# NQ135BD
# Tend to agree                 55
# Strongly agree                36
# Neither agree nor disagree     8
# Tend to disagree               5
# Strongly disagree              2
# Name: count, dtype: int64
#
# Borough: Westminster - Central
# NQ135BD
# Strongly agree                73
# Tend to agree                 30
# Neither agree nor disagree     6
# Strongly disagree              3
# Tend to disagree               2
# Name: count, dtype: int64
#
# Borough: Westminster - North
# NQ135BD
# Strongly agree                67
# Tend to agree                 56
# Neither agree nor disagree    11
# Strongly disagree              6
# Tend to disagree               1
# Name: count, dtype: int64
#
# Borough: Westminster - ORB
# NQ135BD
# Strongly agree    1
# Name: count, dtype: int64
#
# Borough: Westminster - South
# NQ135BD
# Strongly agree                56
# Tend to agree                 40
# Neither agree nor disagree     9
# Strongly disagree              1
# Name: count, dtype: int64
#
# Borough: Westminster - West End
# NQ135BD
# Strongly agree       16
# Tend to agree         6
# Strongly disagree     1
# Name: count, dtype: int64
# C:\Users\20203035\AppData\Local\Temp\ipykernel_15016\2036207264.py:12: DtypeWarning: Columns (41,42,43,131,132,133,213,214,435,444,451) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)

# %% [markdown]
# # This code is to find the percentages of the differnet ethnic groups that have bad results for the relevant question in every borough

# %%
import pandas as pd
import os

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv'

#Name of the columns we want to extract values from
column_name = 'Q13'
disagree_values = ['Fairly worried', 'Very worried']  # Specify the values indicating disagreement
borough_column = 'Borough'    #Adjust according to the file 
ethnic_column = 'ReNQ147'  #The column for the ethnic groups

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Group the DataFrame by the "Borough" column
grouped_df = df.groupby(borough_column)

#Initialize a dictionary to store the percentages of ethnic groups for each borough
ethnic_percentages_by_borough = {}

#Iterate over each borough group
for borough, group_df in grouped_df:
    #Filter the DataFrame to include only responses where respondents disagreed or strongly disagreed
    disagreed_df = group_df[group_df[column_name].isin(disagree_values)]
    
    #Count the occurrences of each ethnic group in the filtered DataFrame
    ethnic_counts = disagreed_df[ethnic_column].value_counts()
    
    #Calculate the total number of responses where respondents disagreed or strongly disagreed
    total_responses = ethnic_counts.sum()
    
    #Calculate the percentages of each ethnic group
    ethnic_percentages = (ethnic_counts / total_responses) * 100
    
    #Store the percentages for the current borough
    ethnic_percentages_by_borough[borough] = ethnic_percentages

#Print the percentages by borough
for borough, ethnic_percentages in ethnic_percentages_by_borough.items():
    print(f"\nBorough: {borough}")
    print(ethnic_percentages)
# Out:
# Borough: Barking & Dagenham
# ReNQ147
# White British    50.193050
# Asian            16.602317
# Black            13.127413
# White Other      11.196911
# Refused           5.405405
# Mixed             3.088803
# Other             0.386100
# Name: count, dtype: float64
#
# Borough: Barnet
# ReNQ147
# White British    46.082949
# White Other      20.276498
# Asian            12.903226
# Black             7.834101
# Refused           6.451613
# Other             3.686636
# Mixed             2.764977
# Name: count, dtype: float64
#
# Borough: Bexley
# ReNQ147
# White British    77.401130
# Asian             7.344633
# Black             5.084746
# White Other       4.519774
# Refused           3.954802
# Mixed             1.694915
# Name: count, dtype: float64
#
# Borough: Brent
# ReNQ147
# Asian            33.587786
# Black            17.938931
# White Other      17.557252
# White British    16.412214
# Refused           8.015267
# Other             4.198473
# Mixed             2.290076
# Name: count, dtype: float64
#
# Borough: Bromley
# ReNQ147
# White British    74.838710
# White Other       8.387097
# Asian             5.161290
# Mixed             4.516129
# Black             3.870968
# Refused           3.225806
# Name: count, dtype: float64
#
# Borough: Camden
# ReNQ147
# White British    50.236967
# White Other      16.113744
# Asian            12.796209
# Black             7.582938
# Refused           5.687204
# Mixed             5.213270
# Other             2.369668
# Name: count, dtype: float64
#
# Borough: Croydon
# ReNQ147
# White British    43.612335
# Asian            18.942731
# Black            18.502203
# White Other      10.572687
# Mixed             4.845815
# Refused           3.083700
# Other             0.440529
# Name: count, dtype: float64
#
# Borough: Ealing
# ReNQ147
# White British    33.628319
# Asian            25.221239
# White Other      19.026549
# Black             9.734513
# Other             4.867257
# Refused           3.982301
# Mixed             3.539823
# Name: count, dtype: float64
#
# Borough: Enfield
# ReNQ147
# White British    40.684411
# White Other      19.771863
# Black            14.828897
# Asian            12.927757
# Mixed             4.942966
# Refused           4.562738
# Other             2.281369
# Name: count, dtype: float64
#
# Borough: Greenwich
# ReNQ147
# White British    53.299492
# White Other      13.197970
# Black            13.197970
# Asian             8.121827
# Refused           7.106599
# Mixed             3.553299
# Other             1.522843
# Name: count, dtype: float64
#
# Borough: Hackney
# ReNQ147
# White British    37.327189
# Black            19.354839
# White Other      17.511521
# Asian            11.981567
# Refused           7.834101
# Mixed             5.529954
# Other             0.460829
# Name: count, dtype: float64
#
# Borough: Hammersmith & Fulham
# ReNQ147
# White British    50.892857
# White Other      19.196429
# Black             9.821429
# Asian             7.142857
# Refused           6.250000
# Other             4.017857
# Mixed             2.678571
# Name: count, dtype: float64
#
# Borough: Haringey
# ReNQ147
# White British    35.6
# White Other      24.8
# Black            18.8
# Asian             8.4
# Refused           6.4
# Mixed             3.6
# Other             2.4
# Name: count, dtype: float64
#
# Borough: Harrow
# ReNQ147
# Asian            42.471042
# White British    32.046332
# White Other      13.127413
# Black             4.247104
# Mixed             3.474903
# Refused           2.702703
# Other             1.930502
# Name: count, dtype: float64
#
# Borough: Havering
# ReNQ147
# White British    78.632479
# Asian             5.982906
# White Other       4.700855
# Black             4.273504
# Refused           3.418803
# Mixed             2.991453
# Name: count, dtype: float64
#
# Borough: Hillingdon
# ReNQ147
# White British    51.694915
# Asian            26.271186
# White Other       9.322034
# Black             5.084746
# Refused           4.237288
# Mixed             1.694915
# Other             1.694915
# Name: count, dtype: float64
#
# Borough: Hounslow
# ReNQ147
# Asian            39.743590
# White British    37.606838
# White Other       8.974359
# Black             5.555556
# Refused           2.991453
# Other             2.564103
# Mixed             2.564103
# Name: count, dtype: float64
#
# Borough: Islington
# ReNQ147
# White British    55.411255
# White Other      19.480519
# Black            12.121212
# Refused           4.761905
# Asian             3.896104
# Mixed             3.463203
# Other             0.865801
# Name: count, dtype: float64
#
# Borough: Kensington & Chelsea
# ReNQ147
# White British    48.223350
# White Other      20.304569
# Refused          10.152284
# Asian             7.614213
# Black             6.091371
# Other             4.568528
# Mixed             3.045685
# Name: count, dtype: float64
#
# Borough: Kingston upon Thames
# ReNQ147
# White British    67.701863
# Asian            11.180124
# White Other      10.559006
# Refused           4.968944
# Black             2.484472
# Other             1.863354
# Mixed             1.242236
# Name: count, dtype: float64
#
# Borough: Lambeth
# ReNQ147
# White British    37.172775
# Black            25.654450
# White Other      19.895288
# Mixed             5.235602
# Other             4.712042
# Refused           4.712042
# Asian             2.617801
# Name: count, dtype: float64
#
# Borough: Lewisham
# ReNQ147
# White British    44.131455
# Black            21.126761
# White Other      16.431925
# Asian             7.981221
# Mixed             5.164319
# Refused           4.694836
# Other             0.469484
# Name: count, dtype: float64
#
# Borough: Merton
# ReNQ147
# White British    50.270270
# White Other      17.837838
# Asian            16.756757
# Black             9.189189
# Mixed             4.324324
# Refused           1.621622
# Name: count, dtype: float64
#
# Borough: Newham
# ReNQ147
# Asian            37.090909
# White British    19.636364
# Black            16.727273
# White Other      16.363636
# Refused           5.090909
# Mixed             4.363636
# Other             0.727273
# Name: count, dtype: float64
#
# Borough: Redbridge
# ReNQ147
# Asian            38.671875
# White British    30.468750
# White Other      10.937500
# Black            10.156250
# Refused           6.250000
# Mixed             2.343750
# Other             1.171875
# Name: count, dtype: float64
#
# Borough: Richmond Upon Thames
# ReNQ147
# White British    76.666667
# White Other      14.000000
# Asian             5.333333
# Refused           2.000000
# Other             0.666667
# Black             0.666667
# Mixed             0.666667
# Name: count, dtype: float64
#
# Borough: Southwark
# ReNQ147
# White British    40.000000
# Black            27.441860
# White Other      17.674419
# Asian             5.581395
# Refused           4.186047
# Mixed             4.186047
# Other             0.930233
# Name: count, dtype: float64
#
# Borough: Sutton
# ReNQ147
# White British    69.005848
# Asian            11.695906
# White Other      10.526316
# Refused           4.093567
# Mixed             1.754386
# Black             1.754386
# Other             1.169591
# Name: count, dtype: float64
#
# Borough: Tower Hamlets
# ReNQ147
# Asian            46.887967
# White British    24.896266
# White Other      11.203320
# Refused           7.468880
# Black             5.809129
# Mixed             2.904564
# Other             0.829876
# Name: count, dtype: float64
#
# Borough: Waltham Forest
# ReNQ147
# White British    34.599156
# Asian            21.940928
# White Other      21.097046
# Black            13.924051
# Mixed             5.063291
# Refused           3.375527
# Name: count, dtype: float64
#
# Borough: Wandsworth
# ReNQ147
# White British    52.571429
# Black            12.000000
# White Other      11.428571
# Asian             9.714286
# Refused           6.857143
# Mixed             5.142857
# Other             2.285714
# Name: count, dtype: float64
#
# Borough: Westminster
# ReNQ147
# White British    41.743119
# White Other      18.348624
# Asian            15.596330
# Other            10.550459
# Black             5.963303
# Refused           4.587156
# Mixed             3.211009
# Name: count, dtype: float64
# C:\Users\20203035\AppData\Local\Temp\ipykernel_15016\835562288.py:14: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)

# %% [markdown]
# # This code is to create a pie chart of the disagreed people from the different ethnic groups in a specific borough

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.pie(ethnic_percentages, labels=ethnic_percentages.index, autopct='%1.1f%%', startangle=0)
plt.title(f'Percentage of Ethnic Groups for {borough_of_interest} where Respondents Disagreed or Strongly Disagreed')
plt.axis('equal')  #Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       3 plt.figure(figsize=(8, 8))
#       4 plt.pie(ethnic_percentages, labels=ethnic_percentages.index, autopct='%1.1f%%', startangle=0)
# ----> 5 plt.title(f'Percentage of Ethnic Groups for {borough_of_interest} where Respondents Disagreed or Strongly Disagreed')
#       6 plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#       7 plt.show()
#
# NameError: name 'borough_of_interest' is not defined

# %% [markdown]
# # This code counts the number of occurrences of the diasgreed people in every borough

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv'

#Name of the column we want to extract values from + the values we are looking for 
column_name = 'XQ122B'
value1 ='Not very confident'
value2 = 'Not at all confident'

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Filter the DataFrame for the first value
filtered_df1 = df[df[column_name] == value1]
# Filter the DataFrame for the second value
filtered_df2 = df[df[column_name] == value2]

#Count the occurrences of each value in each borough
borough_counts1 = filtered_df1['Borough'].value_counts()
borough_counts2 = filtered_df2['Borough'].value_counts()

#Combine the counts for both values
combined_counts = borough_counts1.add(borough_counts2, fill_value=0)

#Sort the combined counts in descending order
combined_counts = combined_counts.sort_values(ascending=False)

#Create a bar plot
plt.figure(figsize=(10, 6))
bar_plot = combined_counts.plot(kind='bar', color='skyblue')
for i, count in enumerate(combined_counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=8)  

plt.title(f'Distribution of Values "{value1}" and "{value2}" Across Boroughs')
plt.xlabel('Borough')
plt.ylabel('Combined Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_18688\136499787.py:14: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)

# %% [markdown]
# # This code counts the percentages of the disagreed people among all the respondents in each borough (this is starting from 19-20 file, because we have to split the column to get the name of the borough)

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_19_20.csv'

#Name of the columns we want to extract values from
column_name = 'Q39A_2'
borough_column = 'BOROUGHNEIGHBOURHOODCODED'
value1 = 'Major problem'
value2 = 'Big problem'

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Extract borough names by splitting the "Borough - Street name" column
df[borough_column] = df[borough_column].str.split(' - ').str[0]

#Filter the dataFrame for the first value
filtered_df1 = df[df[column_name] == value1]

#Filter the dataFrame for the second value
filtered_df2 = df[df[column_name] == value2]

#Count the occurrences of each value in each borough
borough_counts1 = filtered_df1[borough_column].value_counts()
borough_counts2 = filtered_df2[borough_column].value_counts()

#Combine the counts for both values
combined_counts = borough_counts1.add(borough_counts2, fill_value=0)

#Calculate the total counts for each borough
total_counts = df[borough_column].value_counts()

#Calculate the percentages of the desired responses among all responses for each borough
disagree_percentages = (combined_counts / total_counts) * 100

#Sort the percentages in descending order
disagree_percentages = disagree_percentages.sort_values(ascending=False)

#Plotting the percentages
plt.figure(figsize=(10, 6))
bar_plot = disagree_percentages.plot(kind='bar', color='skyblue', width=0.4)
for i, percentage in enumerate(disagree_percentages):
    plt.text(i, percentage + 0.4, f'{percentage:.1f}%', ha='center', va='bottom', fontsize=6.5)

plt.title(f'Percentage of "{value1}" and "{value2}" Responses Among All Responses for Each Borough')
plt.xlabel('Borough')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\2168069034.py:14: DtypeWarning: Columns (41,42,43,131,132,133,213,214,435,444,451) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)

# %% [markdown]
# # This code gives the highest 5 boroughs and the lowest 3 for a specific measure

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_19_20.csv'

#Name of the columns we want to extract values from + values we need 
column_name = 'Q13'
borough_column = 'BOROUGHNEIGHBOURHOODCODED'
value1 = 'Very worried'
Value2 = 'Fairly worried'


#Read the CSV file
df = pd.read_csv(csv_file_path)

#Extract borough names by splitting the "Borough - Street name" column
df[borough_column] = df[borough_column].str.split(' - ').str[0]

#Filter the dataFrame for the first value
filtered_df1 = df[df[column_name] == value1]

#Filter the dataFrame for the second value
filtered_df2 = df[df[column_name] == value2]

#Count the occurrences of each value in each borough
borough_counts1 = filtered_df1[borough_column].value_counts()
borough_counts2 = filtered_df2[borough_column].value_counts()

#Combine the counts for both values
combined_counts = borough_counts1.add(borough_counts2, fill_value=0)

#Calculate the total counts for each borough
total_counts = df[borough_column].value_counts()

#Calculate the percentages of needed responses among all responses for each borough
disagree_percentages = (combined_counts / total_counts) * 100

#Sort the percentages in descending order
disagree_percentages = disagree_percentages.sort_values(ascending=False)

#Round the percentages to two decimal places
disagree_percentages = disagree_percentages.round(2)

#Get the highest 5 boroughs with percentages
highest_5 = disagree_percentages.head(5)

#Get the lowest 3 boroughs with percentages
lowest_3 = disagree_percentages.tail(3)

# Combine highest and lowest into a dataframe
result_df = pd.concat([highest_5, lowest_3], axis=0)

#Reset index to have 'Borough' as a column
result_df = result_df.reset_index()
result_df.columns = ['Borough', 'Percentage']

# Print the result dataframe
result_df
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17960\2978350985.py:15: DtypeWarning: Columns (41,42,43,131,132,133,213,214,435,444,451) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 24
#      21 filtered_df1 = df[df[column_name] == value1]
#      23 #Filter the dataFrame for the second value
# ---> 24 filtered_df2 = df[df[column_name] == value2]
#      26 #Count the occurrences of each value in each borough
#      27 borough_counts1 = filtered_df1[borough_column].value_counts()
#
# NameError: name 'value2' is not defined

# %% [markdown]
# # This code is to get the 5 highest percentages of the last 4 years, with their trends

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Define file paths
file_paths = [
    r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv',
    r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_19_20.csv',
    r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_18_19.csv',
    r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_17_18.csv'
]

#Define columns and values
column_name = 'Q60'
value1 = 'Poor'
value2 = 'Very poor'

#Function to preprocess borough names
def preprocess_borough(borough_name):
    if isinstance(borough_name, str):  
        return borough_name.replace(' and ', ' & ')
    return borough_name  

#Function to process each file and calculate percentages
def process_file(file_path, borough_col, split_borough=False):
    df = pd.read_csv(file_path)
    if split_borough:
        df[borough_col] = df[borough_col].str.split(' - ').str[0]

    #Preprocess borough names
    df[borough_col] = df[borough_col].apply(preprocess_borough)

    #Filter for specified values
    filtered_df1 = df[df[column_name] == value1]
    filtered_df2 = df[df[column_name] == value2]

    #Count occurrences and calculate percentages
    borough_counts1 = filtered_df1[borough_col].value_counts()
    borough_counts2 = filtered_df2[borough_col].value_counts()
    combined_counts = borough_counts1.add(borough_counts2, fill_value=0)
    total_counts = df[borough_col].value_counts()
    percentages = (combined_counts / total_counts) * 100

    return percentages.sort_values(ascending=False)

#Process each file
percentages_list = []
percentages_list.append(process_file(file_paths[0], 'Borough', split_borough=False))

for file_path in file_paths[1:]:
    percentages_list.append(process_file(file_path, 'BOROUGHNEIGHBOURHOODCODED', split_borough=True))

#Reverse the order of percentages_list to match the desired order in the plots
percentages_list = percentages_list[::-1]

#Find the top 5 boroughs for each file
top_boroughs = [percentages.index[:5] for percentages in percentages_list]

#Create dataframes for the top 5 boroughs and their percentages
top_boroughs_dfs = []
for i, percentages in enumerate(percentages_list):
    top_boroughs_df = pd.DataFrame({
        'Borough': percentages.index[:5],
        'Percentage': percentages.values[:5]
    })
    top_boroughs_dfs.append(top_boroughs_df)
    print(f"Top 5 Boroughs for financial year {17+i} - {18+i}:\n", top_boroughs_df, "\n")

#Create line plots for the top 5 boroughs in each file
for i, top_boroughs_list in enumerate(top_boroughs):
    plt.figure(figsize=(12, 6))
    for borough in top_boroughs_list:
        borough_percentages = []
        for percentages in percentages_list:
            borough_percentages.append(percentages.get(borough, 0))
        plt.plot(range(1, 5), borough_percentages, marker='o', label=borough)
    
    plt.title(f'Top 5 Boroughs for financial year {17+i} - {18+i} Across All Years')
    plt.xlabel('Financial Year')
    plt.ylabel('Percentage')
    plt.xticks(range(1, 5), ['17-18','18-19','19-20','20-21'])  # Adjusting x-axis labels to show the correct order
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\580463818.py:25: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\580463818.py:25: DtypeWarning: Columns (41,42,43,131,132,133,213,214,435,444,451) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\580463818.py:25: DtypeWarning: Columns (25,26,27,28,108,109,110,112,113,137,202,203,381) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\580463818.py:25: DtypeWarning: Columns (30,31,32,98,99,100,101,102,103,104,105,125,126,127,199,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Top 5 Boroughs for financial year 17 - 18:
#            Borough  Percentage
# 0         Hackney   11.421320
# 1  Waltham Forest   10.250000
# 2         Croydon    9.677419
# 3   Tower Hamlets    9.644670
# 4        Havering    9.319899
#
# Top 5 Boroughs for financial year 18 - 19:
#            Borough  Percentage
# 0        Haringey   17.587940
# 1         Croydon   16.296296
# 2          Newham   14.936709
# 3  Waltham Forest   14.824121
# 4   Tower Hamlets   13.838120
#
# Top 5 Boroughs for financial year 19 - 20:
#      Borough  Percentage
# 0   Enfield   20.365535
# 1  Haringey   19.083969
# 2   Hackney   15.733333
# 3    Newham   15.733333
# 4    Camden   15.206186
#
# Top 5 Boroughs for financial year 20 - 21:
#           Borough  Percentage
# 0        Hackney   17.543860
# 1  Tower Hamlets   17.293233
# 2      Redbridge   15.869018
# 3         Newham   15.404040
# 4          Brent   14.974619

# %% [markdown]
# # This code counts the percentages of the disagreed people among all the repondents in each borough (Last year)

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv'

#Name of the columns we want to extract values from
column_name = 'Q13'
borough_column = 'Borough'
value1 = 'Very worried'
value2 = 'Fairly worried'

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Filter the DataFrame for the first value
filtered_df1 = df[df[column_name] == value1]
#Filter the DataFrame for the second value
filtered_df2 = df[df[column_name] == value2]

#Count the occurrences of each value in each borough
borough_counts1 = filtered_df1[borough_column].value_counts()
borough_counts2 = filtered_df2[borough_column].value_counts()

#Combine the counts for both values
combined_counts = borough_counts1.add(borough_counts2, fill_value=0)

#Calculate the total counts for each borough
total_counts = df[borough_column].value_counts()

#Calculate the percentages of "Tend to disagree" and "Strongly disagree" responses among all responses for each borough
disagree_percentages = (combined_counts / total_counts) * 100

#Sort the percentages in descending order
disagree_percentages = disagree_percentages.sort_values(ascending=False)

#Plotting the percentages
plt.figure(figsize=(10, 6))

bar_plot = disagree_percentages.plot(kind='bar', color='skyblue',  width=0.4)
for i, percentage in enumerate(disagree_percentages):
    plt.text(i, percentage + 0.4, f'{percentage:.1f}%', ha='center', va='bottom', fontsize= 6.5)

plt.title(f'Percentage of "{value1}" and "{value2}" Responses Among All Responses for Each Borough')
plt.xlabel('Borough')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17444\3339565022.py:15: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)

# %% [markdown]
# # This code creates a dataframe for the best/ worst 3 boroughs for each ethnic group

# %%
import pandas as pd

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv'

#Name of the columns we want to extract values from
column_name = 'NQ135BD'
disagree_values = ['Strongly disagree', 'Tend to disagree']  #Specify the values indicating disagreement
borough_column = 'Borough'
ethnic_column = 'ReNQ147'  # the column for the ethnic groups

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Initialize a dictionary to store the percentages of ethnic groups for each borough
ethnic_percentages_by_borough = {}

#Group the DataFrame by the "Borough" column
grouped_df = df.groupby(borough_column)

#Iterate over each borough group
for borough, group_df in grouped_df:
    #Filter the DataFrame to include only responses where respondents disagreed or strongly disagreed
    disagreed_df = group_df[group_df[column_name].isin(disagree_values)]
    
    #Count the occurrences of each ethnic group in the filtered DataFrame
    ethnic_counts = disagreed_df[ethnic_column].value_counts()
    
    #Calculate the total number of responses where respondents disagreed or strongly disagreed
    total_responses = ethnic_counts.sum()
    
    #Calculate the percentages of each ethnic group
    ethnic_percentages = (ethnic_counts / total_responses) * 100
    
    #Store the percentages for the current borough
    ethnic_percentages_by_borough[borough] = ethnic_percentages

#Convert the dictionary to a DataFrame
ethnic_percentages_df = pd.DataFrame(ethnic_percentages_by_borough).transpose().fillna(0)

#Initialize dictionaries to store top and bottom 3 boroughs with percentages
top_bottom_boroughs = {
    'Ethnic Group': [],
    'Top 3 Boroughs': [],
    'Top 3 Percentages': [],
    'Bottom 3 Boroughs': [],
    'Bottom 3 Percentages': []
}

#Find the top 3 and bottom 3 boroughs for each ethnic group
for ethnic_group in ethnic_percentages_df.columns:
    sorted_boroughs = ethnic_percentages_df[ethnic_group].sort_values(ascending=False)
    top_3 = sorted_boroughs.head(3).index
    bottom_3 = sorted_boroughs.tail(3).index
    top_3_percentages = sorted_boroughs.head(3).values
    bottom_3_percentages = sorted_boroughs.tail(3).values
    
    top_bottom_boroughs['Ethnic Group'].append(ethnic_group)
    top_bottom_boroughs['Top 3 Boroughs'].append(', '.join(top_3))
    top_bottom_boroughs['Top 3 Percentages'].append(', '.join(f"{percent:.2f}%" for percent in top_3_percentages))
    top_bottom_boroughs['Bottom 3 Boroughs'].append(', '.join(bottom_3))
    top_bottom_boroughs['Bottom 3 Percentages'].append(', '.join(f"{percent:.2f}%" for percent in bottom_3_percentages))

#Create a DataFrame to display the results
top_bottom_boroughs_df = pd.DataFrame(top_bottom_boroughs)
top_bottom_boroughs_df
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_15016\2840012164.py:13: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#     Ethnic Group                             Top 3 Boroughs  \
# 0          Asian          Hillingdon, Harrow, Tower Hamlets
# 1          Black                    Brent, Lambeth, Croydon
# 2          Mixed         Harrow, Barking & Dagenham, Camden
# 3          Other  Ealing, Westminster, Kensington & Chelsea
# 4        Refused                Islington, Camden, Haringey
# 5  White British     Kingston upon Thames, Havering, Bexley
# 6    White Other        Westminster, Waltham Forest, Barnet
#
#         Top 3 Percentages                          Bottom 3 Boroughs  \
# 0  41.18%, 37.04%, 32.43%                Lambeth, Bexley, Wandsworth
# 1  51.35%, 51.11%, 50.00%   Hillingdon, Sutton, Kingston upon Thames
# 2  22.22%, 20.00%, 14.71%               Tower Hamlets, Brent, Bexley
# 3    12.50%, 6.90%, 6.45%                 Hackney, Croydon, Hounslow
# 4  18.42%, 17.65%, 16.67%  Hillingdon, Greenwich, Barking & Dagenham
# 5  71.43%, 56.52%, 50.00%                      Harrow, Newham, Brent
# 6  20.69%, 18.42%, 16.67%        Croydon, Bexley, Barking & Dagenham
#
#      Bottom 3 Percentages
# 0     0.00%, 0.00%, 0.00%
# 1   11.76%, 11.54%, 0.00%
# 2     2.70%, 2.70%, 0.00%
# 3     0.00%, 0.00%, 0.00%
# 4     0.00%, 0.00%, 0.00%
# 5  14.81%, 11.43%, 10.81%
# 6     2.63%, 0.00%, 0.00%

# %% [markdown]
# # This code gets you the highest given answer + its percentage in every borough for a specific question

# %%
import pandas as pd

#Define the path to the CSV file
csv_file_path = r'C:\Users\20203035\OneDrive - TU Eindhoven\Desktop\Real work\real work\Data Challenge 2\Data\pas_data_ward_level\PAS_ward_level_FY_20_21.csv'

#Name of the columns we want to extract values from
column_name = 'XQ122B'
borough_column = 'Borough'

#Read the CSV file
df = pd.read_csv(csv_file_path)

#Group the DataFrame by the "Borough" column
grouped_df = df.groupby(borough_column)

#Initialize a list to store the result
result_data = []

#Iterate over each borough group
for borough, group_df in grouped_df:
    #Get the occurrences of values for the specified column
    value_counts = group_df[column_name].value_counts()
    
    #Find the highest value and its count
    most_common_answer = value_counts.idxmax()
    most_common_answer_count = value_counts.max()
    
    #Calculate the percentage of the most occurring answer among all the given answers
    total_answers = value_counts.sum()
    percentage = (most_common_answer_count / total_answers) * 100
    result_data.append({'Borough': borough,
                        'Most Common Answer': f'{most_common_answer} ({most_common_answer_count})',
                        'Percentage': percentage})


result_df = pd.DataFrame(result_data)
result_df
# Out:
# C:\Users\20203035\AppData\Local\Temp\ipykernel_17960\2471976146.py:11: DtypeWarning: Columns (10,11,12,13,17,24,33,34,46,47,48,49,50,51,52,53,59,60,61,64,65,66,67,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,107,108,109,110,112,113,114,115,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#                  Borough       Most Common Answer  Percentage
# 0     Barking & Dagenham    Fairly confident (38)   42.696629
# 1                 Barnet    Fairly confident (39)   48.148148
# 2                 Bexley    Fairly confident (50)   59.523810
# 3                  Brent    Fairly confident (33)   41.772152
# 4                Bromley    Fairly confident (52)   64.197531
# 5                 Camden    Fairly confident (43)   53.086420
# 6                Croydon    Fairly confident (46)   55.421687
# 7                 Ealing    Fairly confident (46)   56.790123
# 8                Enfield    Fairly confident (43)   52.439024
# 9              Greenwich    Fairly confident (47)   55.952381
# 10               Hackney    Fairly confident (30)   38.461538
# 11  Hammersmith & Fulham    Fairly confident (37)   49.333333
# 12              Haringey    Fairly confident (36)   46.153846
# 13                Harrow    Fairly confident (45)   51.724138
# 14              Havering    Fairly confident (53)   63.855422
# 15            Hillingdon    Fairly confident (55)   63.953488
# 16              Hounslow    Fairly confident (39)   44.318182
# 17             Islington    Fairly confident (39)   48.750000
# 18  Kensington & Chelsea    Fairly confident (44)   53.658537
# 19  Kingston upon Thames    Fairly confident (44)   56.410256
# 20               Lambeth    Fairly confident (30)   39.473684
# 21              Lewisham    Fairly confident (41)   50.617284
# 22                Merton    Fairly confident (50)   57.471264
# 23                Newham    Fairly confident (35)   41.176471
# 24             Redbridge    Fairly confident (34)   43.589744
# 25  Richmond Upon Thames    Fairly confident (46)   55.421687
# 26             Southwark    Fairly confident (40)   45.977011
# 27                Sutton    Fairly confident (44)   55.696203
# 28         Tower Hamlets    Fairly confident (48)   54.545455
# 29        Waltham Forest  Not very confident (34)   38.636364
# 30            Wandsworth    Fairly confident (37)   45.679012
# 31           Westminster    Fairly confident (41)   53.947368
