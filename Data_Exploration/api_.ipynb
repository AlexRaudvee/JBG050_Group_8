# %%
import json
import requests

import pandas as pd
import geopandas as gpd

from datetime import datetime

# %%
def extract_forces_api(type: str = None):

    base_url = 'https://data.police.uk/api/forces'
    if type == None:
        url = base_url
    elif 'leicestershire' == type.lower():
        url = base_url + '/' + type.lower()
    elif 'leicestershire/people' == type.lower():
        url = base_url + '/' + type.lower()

    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    return list_of_dict

# %%
extract_forces_api()
# Out:
# [{'id': 'avon-and-somerset', 'name': 'Avon and Somerset Constabulary'},
#  {'id': 'bedfordshire', 'name': 'Bedfordshire Police'},
#  {'id': 'cambridgeshire', 'name': 'Cambridgeshire Constabulary'},
#  {'id': 'cheshire', 'name': 'Cheshire Constabulary'},
#  {'id': 'city-of-london', 'name': 'City of London Police'},
#  {'id': 'cleveland', 'name': 'Cleveland Police'},
#  {'id': 'cumbria', 'name': 'Cumbria Constabulary'},
#  {'id': 'derbyshire', 'name': 'Derbyshire Constabulary'},
#  {'id': 'devon-and-cornwall', 'name': 'Devon & Cornwall Police'},
#  {'id': 'dorset', 'name': 'Dorset Police'},
#  {'id': 'durham', 'name': 'Durham Constabulary'},
#  {'id': 'dyfed-powys', 'name': 'Dyfed-Powys Police'},
#  {'id': 'essex', 'name': 'Essex Police'},
#  {'id': 'gloucestershire', 'name': 'Gloucestershire Constabulary'},
#  {'id': 'greater-manchester', 'name': 'Greater Manchester Police'},
#  {'id': 'gwent', 'name': 'Gwent Police'},
#  {'id': 'hampshire', 'name': 'Hampshire Constabulary'},
#  {'id': 'hertfordshire', 'name': 'Hertfordshire Constabulary'},
#  {'id': 'humberside', 'name': 'Humberside Police'},
#  {'id': 'kent', 'name': 'Kent Police'},
#  {'id': 'lancashire', 'name': 'Lancashire Constabulary'},
#  {'id': 'leicestershire', 'name': 'Leicestershire Police'},
#  {'id': 'lincolnshire', 'name': 'Lincolnshire Police'},
#  {'id': 'merseyside', 'name': 'Merseyside Police'},
#  {'id': 'metropolitan', 'name': 'Metropolitan Police Service'},
#  {'id': 'norfolk', 'name': 'Norfolk Constabulary'},
#  {'id': 'north-wales', 'name': 'North Wales Police'},
#  {'id': 'north-yorkshire', 'name': 'North Yorkshire Police'},
#  {'id': 'northamptonshire', 'name': 'Northamptonshire Police'},
#  {'id': 'northumbria', 'name': 'Northumbria Police'},
#  {'id': 'nottinghamshire', 'name': 'Nottinghamshire Police'},
#  {'id': 'northern-ireland', 'name': 'Police Service of Northern Ireland'},
#  {'id': 'south-wales', 'name': 'South Wales Police'},
#  {'id': 'south-yorkshire', 'name': 'South Yorkshire Police'},
#  {'id': 'staffordshire', 'name': 'Staffordshire Police'},
#  {'id': 'suffolk', 'name': 'Suffolk Constabulary'},
#  {'id': 'surrey', 'name': 'Surrey Police'},
#  {'id': 'sussex', 'name': 'Sussex Police'},
#  {'id': 'thames-valley', 'name': 'Thames Valley Police'},
#  {'id': 'warwickshire', 'name': 'Warwickshire Police'},
#  {'id': 'west-mercia', 'name': 'West Mercia Police'},
#  {'id': 'west-midlands', 'name': 'West Midlands Police'},
#  {'id': 'west-yorkshire', 'name': 'West Yorkshire Police'},
#  {'id': 'wiltshire', 'name': 'Wiltshire Police'}]

# %% [markdown]
# # Crime related

# %%
def extract_street_level_crimes(lat: float = None, lng: float = None, date: str = None, poly: tuple = None, crime_type: str = None):
    """
    Params:
    lat - Latitude of the requested crime area
    lng - Longitude of the requested crime area
    date - Optional. "YYYY-MM" Limit results to a specific month. The latest month will be shown by default
    OR: 
    poly - Limit results to a specific area. The lat/lng pairs which define the boundary of the custom area

    You can also specify the type of crime:
    crime_type - The type of crime. Options are: None, anti-social-behavior, burglary
    """
    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    if crime_type == None:
        base_url = "https://data.police.uk/api/crimes-street/all-crime?"
    elif crime_type != None:
        base_url = f"https://data.police.uk/api/crimes-street/{crime_type}?"

    if date == None:
        if lat and lng != None:
            url = base_url + f"lat={lat}&lng={lng}&date={current_year}-{current_month}"
        elif poly != None:
            url = base_url + f"poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]},{poly[2][1]}&date={current_year}-{current_month}"
        else:
            raise ValueError(f'Specify the lat/lng, you passed {lat, lng} or poly {poly}')
    
    elif date != None:
        if lat and lng != None:
            url = base_url + f"lat={lat}&lng={lng}&date={date}"
        elif poly != None:
            url = base_url + f"poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]}:{poly[2][1]}&date={date}"
        else:
            raise ValueError(f'Specify the lat/lang, you passed {lat, lng} or poly {poly}')
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_street_level_crimes(lat=51.549740625151905, lng=0.22074769211139364, date='2023-04', crime_type='burglary')
# Out:
# [{'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.549919',
#    'street': {'id': 1709284, 'name': 'On or near Fernbank Avenue'},
#    'longitude': '0.208614'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': 'd0b9e31ded76b21f4b5466c871434c61608874f36d35193e5976d32c8a3a5fdb',
#   'id': 109591492,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.558207',
#    'street': {'id': 1710134, 'name': 'On or near Supermarket'},
#    'longitude': '0.238649'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': 'bd624bb6bd9867e2caa128950267a9f287049a81a0b99d1fde493f69446539a8',
#   'id': 109588353,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.559543',
#    'street': {'id': 1710019, 'name': 'On or near Upminster Road'},
#    'longitude': '0.233232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-04'},
#   'persistent_id': '1796b097c0dc1086dc3c0158a4bd8b1283c52f655d6e91cfc0da7f151137cfa3',
#   'id': 109596880,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': '1c0edf9429e38153e8e89c88cc339da171e14520787ffef294e8bb90e035559e',
#   'id': 109588351,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.562017',
#    'street': {'id': 1709654, 'name': 'On or near Appleton Way'},
#    'longitude': '0.218492'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-06'},
#   'persistent_id': 'd3003fcadd98f351f2e24fc932315727873baec7155ad66f280670f7b1220ccc',
#   'id': 109531363,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.549636',
#    'street': {'id': 1710072, 'name': 'On or near Hornbeam Avenue'},
#    'longitude': '0.234925'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': 'bfc19e63216f2e2533f0c9443ab9ae8f75f9610fbafbf28ead15d745fcb1fd37',
#   'id': 109528377,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.546556',
#    'street': {'id': 1709265, 'name': 'On or near Elms Farm Road'},
#    'longitude': '0.207168'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': '63d8beaefaca5194ce9ae01a6693066aaa3c78ade24d138554d4f48edf20cec3',
#   'id': 109512056,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.547798',
#    'street': {'id': 1709183, 'name': 'On or near Lancaster Drive'},
#    'longitude': '0.205179'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-04'},
#   'persistent_id': '3deab8b24c23de1276178cf688250d288b8ee7eb4b6891a5054f9fffe9bb1cbe',
#   'id': 109504828,
#   'location_subtype': '',
#   'month': '2023-04'}]

# %%
path_to_PAS = '../data/PAS_T%26Cdashboard_to%20Q3%2023-24'

df_PAS_Borough = pd.read_csv(f'{path_to_PAS}_Borough.csv')

df_PAS_Borough = df_PAS_Borough.loc[:, ~df_PAS_Borough.columns.str.contains('^Unnamed')]
df_PAS_Borough = df_PAS_Borough.dropna(axis=1, how='all')

# Preprocess the data for Borough
df_PAS_Borough['Date'] = df_PAS_Borough['Date'].apply(lambda x: x[:7])
df_PAS_Borough['Borough'] = df_PAS_Borough['Borough'].apply(lambda x: 'Westminster' if x == 'City of Westminster' else x)
df_PAS_Borough.loc[df_PAS_Borough['Borough'] == 'Richmond Upon Thames', 'Borough'] = 'Richmond upon Thames'

df_PAS_Borough
# Out:
#          Date Survey               Borough            Measure  Proportion  \
# 0     2014-12    PAS  Barking and Dagenham   "Good Job" local        0.56
# 1     2014-12    PAS                Barnet   "Good Job" local        0.67
# 2     2014-12    PAS                Bexley   "Good Job" local        0.72
# 3     2014-12    PAS                 Brent   "Good Job" local        0.66
# 4     2014-12    PAS               Bromley   "Good Job" local        0.71
# ...       ...    ...                   ...                ...         ...
# 9307  2023-12    PAS                Sutton  Understand issues        0.66
# 9308  2023-12    PAS         Tower Hamlets  Understand issues        0.55
# 9309  2023-12    PAS        Waltham Forest  Understand issues        0.39
# 9310  2023-12    PAS            Wandsworth  Understand issues        0.56
# 9311  2023-12    PAS           Westminster  Understand issues        0.67
#
#        MPS
# 0     0.67
# 1     0.67
# 2     0.67
# 3     0.67
# 4     0.67
# ...    ...
# 9307  0.57
# 9308  0.57
# 9309  0.57
# 9310  0.57
# 9311  0.57
#
# [9312 rows x 6 columns]

# %%
from leafmap import Map
import leafmap as leafmap
from shapely.geometry import Point
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors


def on_map_click(event, map_instance, df):
    
    if event['type'] == 'click':  # Check for left-click
        lat, lon = event['coordinates']
        print("Latitude:", lat)
        print("Longitude:", lon)

        def in_polygon(polygon):
            point = Point(lon, lat)
            return polygon.contains(point)
        
        # Find the clicked neighborhood
        for index, row in df.iterrows():
            
            if in_polygon(row['geometry']):
                neighborhood_name = row['name']
                coordinates = row['geometry']
                print("Clicked Neighborhood:", neighborhood_name)
                print("Polygon Coordinates:", coordinates)
                break

        

def create_map():
    # Create a map centered around London
    m = Map(center=(51.5074, -0.1278), zoom=10)

    # Load the geojson file for the boroughs
    neighbourhoods = gpd.read_file('../data/neighbourhoods_boundary.geojson')

    # Load the data for the specific date and measure
    filtered_data = df_PAS_Borough[(df_PAS_Borough['Date'].str.contains(str('2023-12'))) & (df_PAS_Borough['Measure'] == 'Understand issues')]

    # Merge the filtered data with the boroughs data
    merged_data = gpd.GeoDataFrame(neighbourhoods.merge(filtered_data, left_on='borough', right_on='Borough'))

    def proportional_color(feature):
        # Get the value indicating proportion from the DataFrame
        proportion_value = feature['properties']['Proportion']

        # Define a colormap
        cmap = LinearSegmentedColormap.from_list('proportional_color', ['red', 'yellow', 'green'])
        
        # Map the proportion value to a color
        color = cmap(proportion_value)

        # Convert the color to HTML color code
        html_color = mcolors.rgb2hex(color)
        
        return {
            'color': 'black',
            'fillColor': html_color,
        }

    # Add a GeoJson layer to the map
    geojson_layer = leafmap.geojson_layer(
        in_geojson=merged_data._to_geo(), 
        style={'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
        hover_style={'fillColor': 'red'},
        style_callback=proportional_color,
    )
    
    m.add_layer(geojson_layer)
    
    # Add a click event handler to the map
    def click_handler(event=None, **kwargs):
        clicked = on_map_click(kwargs, m, merged_data)
        if clicked is not None:
            print("Clicked points:", clicked)

    m.on_interaction(click_handler)

    # Display the map
    return m

create_map()
# Out:
# DeltaGenerator()

# %%
def extract_street_level_outcomes(location_id: int = None, lat: float = None, lng: float = None, date: str = None, poly: list = None):
    """
    Params:
    lat - Latitude of the requested crime area
    lng - Longitude of the requested crime area
    date - Optional. "YYYY-MM" Limit results to a specific month. 
        The latest month will be shown by default
    poly - The lat/lng pairs which define the boundary of the custom area. 
        The poly parameter is formatted in lat/lng pairs, separated by 
        colons: [lat],[lng]:[lat],[lng]:[lat],[lng]
    location_id - Crimes and outcomes are mapped to specific locations on the map. 
        Valid IDs are returned by other methods which return location information.
    """

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    base_url = 'https://data.police.uk/api/outcomes-at-location?'

    if date == None:
        if lat and lng != None:
            url = base_url + f"date={current_year}-{current_month}&lat={lat}&lng={lng}"
        elif poly != None:
            url = base_url + f"date={current_year}-{current_month}&poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]},{poly[2][1]}"
        elif location_id != None:
            url = base_url + f"date={current_year}-{current_month}&location_id={location_id}"
        else:
            raise ValueError(f'Specify the lat/lang or poly or location_id that you passed or make sure they are correct: location_id-{location_id}, lat/lang-{lat, lng}, poly={poly}')
    
    elif date != None:
        if lat and lng != None:
            url = base_url + f"date={date}&lat={lat}&lng={lng}"
        elif poly != None:
            url = base_url + f"date={date}&poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]}:{poly[2][1]}"
        elif location_id != None:
            url = base_url + f"date={date}&location_id={location_id}"
        else:
            raise ValueError(f'Specify the lat/lang or poly or location_id that you passed or make sure they are correct: location_id-{location_id}, lat/lang-{lat, lng}, poly={poly}')
        
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_street_level_outcomes(location_id=1709052, date='2023-04')
# Out:
# [{'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'violent-crime',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '99153a619aa37e592722b1d58bcc742ae08042b18bb944b731b0ad595bc19ec9',
#    'id': 103333792,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2022-07'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'violent-crime',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '99153a619aa37e592722b1d58bcc742ae08042b18bb944b731b0ad595bc19ec9',
#    'id': 103333792,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2022-07'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'violent-crime',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '99153a619aa37e592722b1d58bcc742ae08042b18bb944b731b0ad595bc19ec9',
#    'id': 103333792,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2022-07'}},
#  {'category': {'code': 'local-resolution', 'name': 'Local resolution'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'shoplifting',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': 'a5bae48d9396f9a3124e7b79d0adc4cf7631a4ef8d53b8497be53ef27171f09c',
#    'id': 108973452,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-03'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'shoplifting',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '9e687b0014a9d96f0e493a15dc6bc76495a20753b694c19cad995e853c98a9cf',
#    'id': 108944981,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-03'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'shoplifting',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '9e687b0014a9d96f0e493a15dc6bc76495a20753b694c19cad995e853c98a9cf',
#    'id': 108944981,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-03'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'violent-crime',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': 'e4e12ed0167aab0a3ef24aa1ea24be2e3d49d8426f3ea9e8a6960061ab231e0b',
#    'id': 107846125,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-01'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'shoplifting',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '88bbbcc92436c885d84223aff9ae6ce53e04cc412ce34d360140e8f273f24524',
#    'id': 109033033,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-03'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'public-order',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '635bc1eb6a60e1bbebcaa91b33beb398ef1c8e4e84f7b1ad9e4e37a3fa6c4a70',
#    'id': 107892024,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-01'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'criminal-damage-arson',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': 'ea51259eb4b549aa705bc836ee01e117a155f845e1b1dee58309854dc9f65aef',
#    'id': 107866833,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-01'}},
#  {'category': {'code': 'local-resolution', 'name': 'Local resolution'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'public-order',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '9f9ee4d817a423dc9546886c36f40ce400c6da409d84ba8c1c1c26b3efdfcde3',
#    'id': 109509616,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-04'}},
#  {'category': {'code': 'no-further-action',
#    'name': 'Investigation complete; no suspect identified'},
#   'date': '2023-04',
#   'person_id': None,
#   'crime': {'category': 'violent-crime',
#    'location_type': 'Force',
#    'location': {'latitude': '51.548660',
#     'street': {'id': 1709052, 'name': ' '},
#     'longitude': '0.199232'},
#    'context': '',
#    'persistent_id': '877f8aa42ba3fd215c39a71f108f8b46528b7aaf22ec1ee7bb50be5b5f2d0c66',
#    'id': 108979777,
#    'location_subtype': 'SUPERMARKET CHAINS',
#    'month': '2023-03'}}]

# %%
def extract_crimes_at_location(location_id: int = None, lat: float = None, lng: float = None, date: str = None):
    """
    Params:
    lat - Latitude of the requested crime area
    lng - Longitude of the requested crime area
    date - Optional. "YYYY-MM" Limit results to a specific month. 
        The latest month will be shown by default
    location_id - Crimes and outcomes are mapped to specific locations on the map. 
        Valid IDs are returned by other methods which return location information.
    """

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    base_url = 'https://data.police.uk/api/crimes-at-location?'

    if date == None:
        if lat and lng != None:
            url = base_url + f"date={current_year}-{current_month}&lat={lat}&lng={lng}"
        elif location_id != None:
            url = base_url + f"date={current_year}-{current_month}&location_id={location_id}"
        else:
            raise ValueError(f'Specify the lat/lang or location_id that you passed or make sure they are correct: location_id-{location_id}, lat/lang-{lat, lng}')
    
    elif date != None:
        if lat and lng != None:
            url = base_url + f"date={date}&lat={lat}&lng={lng}"
        elif location_id != None:
            url = base_url + f"date={date}&location_id={location_id}"
        else:
            raise ValueError(f'Specify the lat/lang or location_id that you passed or make sure they are correct: location_id-{location_id}, lat/lang-{lat, lng}')
        
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_crimes_at_location(location_id=1709052, date='2023-04')
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near '},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 109492434,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': '1c0edf9429e38153e8e89c88cc339da171e14520787ffef294e8bb90e035559e',
#   'id': 109588351,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'public-order',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near '},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Local resolution', 'date': '2023-04'},
#   'persistent_id': '9f9ee4d817a423dc9546886c36f40ce400c6da409d84ba8c1c1c26b3efdfcde3',
#   'id': 109509616,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'shoplifting',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': '7e4941549082fc741cd9d2528728f6f915117263f190d503aadc0d2146ce712a',
#   'id': 109600498,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'shoplifting',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': 'e45e1533f9b6db053d22cf7f5bec5b77b0d8974ec8dc266bf8b7ed56f73cc0ee',
#   'id': 109596245,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'shoplifting',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-12'},
#   'persistent_id': '2cb9ffe3a5e25c56efec439ef3ec30194c32160a1ececa93c0c88fa29306c6de',
#   'id': 109604391,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'vehicle-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-05'},
#   'persistent_id': 'cfa827852a0f12da18bdaf664f64bfb40edd5b0ad4a0cfc3bb78b4479b7acabc',
#   'id': 109597285,
#   'location_subtype': '',
#   'month': '2023-04'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-07'},
#   'persistent_id': '454c6360b98948a3a06c6f2627f2e6c97cc76dff063c93977c4a64f266b7d527',
#   'id': 109527346,
#   'location_subtype': '',
#   'month': '2023-04'}]

# %%
def extract_crimes_no_location(category: str = 'all-crime', force: str = 'leicestershire', date: str = None):
    """
    Params:
    category - The type of crime. Options are: None, anti-social-behaviour, burglary
    date - Optional. "YYYY-MM" Limit results to a specific month. 
        The latest month will be shown by default
    location_id - Crimes and outcomes are mapped to specific locations on the map. 
        Valid IDs are returned by other methods which return location information.
    """

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    base_url = 'https://data.police.uk/api/crimes-no-location?'

    if date == None:
        if (category and force) != None:
            url = base_url + f"category={category}&force={force}&date={current_year}-{current_month}"
        else:
            raise ValueError(f'Specify the category and force that you passed or make sure they are correct: category-{category}, force-{force}')
    
    elif date != None:
        if (category and force) != None:
            url = base_url + f"category={category}&force={force}&date={date}"
        else:
            raise ValueError(f'Specify the category and force that you passed or make sure they are correct: category-{category}, force-{force}')
    
    else: 
        raise ValueError(f'Specify the date, you passed: date={date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_crimes_no_location(category='all-crime', date='2024-01', force='leicestershire')
# Out:
# [{'category': 'bicycle-theft',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-02'},
#   'persistent_id': '3cce1d68d447e230f4d341552260b75a444355d2c2dc89052363a235b9b43902',
#   'id': 116203234,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'bicycle-theft',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-02'},
#   'persistent_id': '2dfbe17ccd04260ea94db37ae5d759078cd728430c668c84b5b8b1a08ec253ca',
#   'id': 116205668,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2024-01'},
#   'persistent_id': '1435974b6758d2d3be4da594a84913877173485d6a39c70a25841f1e1ce28459',
#   'id': 116206380,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2024-01'},
#   'persistent_id': 'bee75b109d76dfbe909e2e8ffeedd2d47878e55a2d9a019e61c28053eeec93b7',
#   'id': 116203804,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id': '0d2eb297aa69cb1f9d5cb407bf4f3f24af2f76fff3189f49fe5be6cc65c30e7d',
#   'id': 116207345,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-02'},
#   'persistent_id': 'd432e9fa1b159a089784485e1df1c67fd8daec0e546ebb9e12b64c7ffd40d7bd',
#   'id': 116207574,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id': 'fa2dbcf6866f35e420fd31cadfcdacc326f4d4b0da67cb27853fa6885269cba3',
#   'id': 116201158,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2024-01'},
#   'persistent_id': '5085e5f3759e28661457a4562a418377e0251895b3c04690cb43d6b32a6a187f',
#   'id': 116201162,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id': '0d81f946151d02d70b3d34eb942b2d4e7a34e1a49d8381b18a4b12a3f27e02df',
#   'id': 116200998,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id': 'e146d700fe1a9e2e8b4d59a1e81350a155252bb4efd572b72ad0ca816e358aef',
#   'id': 116200990,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'burglary',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id':

#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'other-crime',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Unable to prosecute suspect',
#    'date': '2024-02'},
#   'persistent_id': 'ac6c21bc8d0e6a487a13f83ab031b78c813c989ea216cbd4671c595d294d0de8',
#   'id': 116208548,
#   'location_subtype': '',
#   'month': '2024-01'},
#  {'category': 'other-crime',
#   'location_type': None,
#   'location': None,
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2024-01'},
#   'persistent_id': 'e6d05af34f4b905361c56722be5841b00a2b11dbde624b398209d28966959af2',
#   'id': 116203788,
#   'location_subtype': '',
#   'month': '2024-01'}]

# %%
def extract_crimes_categories_at_date(date: str = None):
    """
    Params:
    date - Optional. "YYYY-MM" Limit results to a specific month. 
        The latest month will be shown by default
    """

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    base_url = 'https://data.police.uk/api/crime-categories?'

    if date == None:
        
        url = base_url + f"date={current_year}-{current_month}"
        
    elif date != None:
        
        url = base_url + f"date={date}"
       
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_crimes_categories_at_date(date='2023-04')
# Out:
# [{'url': 'all-crime', 'name': 'All crime'},
#  {'url': 'anti-social-behaviour', 'name': 'Anti-social behaviour'},
#  {'url': 'bicycle-theft', 'name': 'Bicycle theft'},
#  {'url': 'burglary', 'name': 'Burglary'},
#  {'url': 'criminal-damage-arson', 'name': 'Criminal damage and arson'},
#  {'url': 'drugs', 'name': 'Drugs'},
#  {'url': 'other-theft', 'name': 'Other theft'},
#  {'url': 'possession-of-weapons', 'name': 'Possession of weapons'},
#  {'url': 'public-order', 'name': 'Public order'},
#  {'url': 'robbery', 'name': 'Robbery'},
#  {'url': 'shoplifting', 'name': 'Shoplifting'},
#  {'url': 'theft-from-the-person', 'name': 'Theft from the person'},
#  {'url': 'vehicle-crime', 'name': 'Vehicle crime'},
#  {'url': 'violent-crime', 'name': 'Violence and sexual offences'},
#  {'url': 'other-crime', 'name': 'Other crime'}]

# %%
def extract_last_updated():
    
    url = 'https://data.police.uk/api/crime-last-updated'

    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_last_updated()
# Out:
# {'date': '2024-03-01'}

# %%
def extract_outcome_for_specific_crime(crime_id: str = None):
    """
    Returns the outcomes (case history) for the specified crime.
    Note: Outcomes are not available for the Police Service of Northern Ireland.

    Parameters:
    crime_id is 64-character identifier
    """

    base_url = 'https://data.police.uk/api/outcomes-for-crime/'

    if crime_id != None:
        url = base_url + f"{crime_id}"
    elif crime_id == None:
        raise ValueError(f"Specify the crime_id that you passed and make sure it's correct: crime_id={crime_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_outcome_for_specific_crime(crime_id='1c0edf9429e38153e8e89c88cc339da171e14520787ffef294e8bb90e035559e')
# Out:
# {'outcomes': [{'category': {'code': 'under-investigation',
#     'name': 'Under investigation'},
#    'date': '2023-04',
#    'person_id': None},
#   {'category': {'code': 'no-further-action',
#     'name': 'Investigation complete; no suspect identified'},
#    'date': '2023-07',
#    'person_id': None}],
#  'crime': {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '51.548660',
#    'street': {'id': 1709052, 'name': 'On or near Supermarket'},
#    'longitude': '0.199232'},
#   'context': '',
#   'persistent_id': '1c0edf9429e38153e8e89c88cc339da171e14520787ffef294e8bb90e035559e',
#   'id': 109588351,
#   'location_subtype': '',
#   'month': '2023-04'}}

# %% [markdown]
# # Neighbourhood related

# %%
def extract_neighbourhoods_for_a_force(force: str = 'leicestershire'):
    """
    Returns the neighbourhoods for the specified force.
    Parameters:
    force - string that represents the name of force (default: 'leicestershire')
    """

    if force != None:
        url = f'https://data.police.uk/api/{force}/neighbourhoods'

    elif force == None:
        raise ValueError(f"Specify the force that you passed and make sure it's correct: force={force}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbourhoods_for_a_force(force='leicestershire')
# Out:
# [{'id': 'NC04', 'name': 'City Centre'},
#  {'id': 'NC66', 'name': 'Cultural Quarter'},
#  {'id': 'NC67', 'name': 'Riverside'},
#  {'id': 'NC68', 'name': 'Clarendon Park'},
#  {'id': 'NE09', 'name': 'Latimer'},
#  {'id': 'NE10', 'name': 'Belgrave'},
#  {'id': 'NE11', 'name': 'Rushey Mead'},
#  {'id': 'NE12', 'name': 'Humberstone and Hamilton'},
#  {'id': 'NE13', 'name': 'Northfields, Tailby and Morton'},
#  {'id': 'NE14', 'name': 'Thurncourt'},
#  {'id': 'NE15', 'name': 'Stoneygate'},
#  {'id': 'NE16', 'name': 'Spinney Hills'},
#  {'id': 'NE17', 'name': 'Evington'},
#  {'id': 'NE18', 'name': 'Coleman'},
#  {'id': 'NH19', 'name': 'Thorpe Astley and Braunstone Town'},
#  {'id': 'NH20', 'name': 'Enderby, Narborough, Littlethorpe and Fosse Park'},
#  {'id': 'NH21', 'name': 'Blaby, Whetstone, Glen Parva and Cosby'},
#  {'id': 'NH22', 'name': 'Leicester Forest East, Kirby Muxloe and Glenfield'},
#  {'id': 'NH23', 'name': 'Countesthorpe, Foston and Kilby'},
#  {'id': 'NH24', 'name': 'Fosse Villages'},
#  {'id': 'NH25', 'name': 'Hinckley Town Centre'},
#  {'id': 'NH26', 'name': 'Greater Hinckley'},
#  {'id': 'NH27', 'name': 'Earl Shilton and Barwell'},
#  {'id': 'NH28', 'name': 'Burbage'},
#  {'id': 'NH29', 'name': 'Bosworth, Ratby, Groby, Markfield and Stanton'},
#  {'id': 'NL56', 'name': 'Charnwood West'},
#  {'id': 'NL57', 'name': 'Mountsorrel'},
#  {'id': 'NL58', 'name': 'Anstey'},
#  {'id': 'NL59', 'name': 'Charnwood North'},
#  {'id': 'NL60', 'name': 'Birstall'},
#  {'id': 'NL61', 'name': 'Charnwood East'},
#  {'id': 'NL62', 'name': 'Loughborough Central'},
#  {'id': 'NL63', 'name': 'Loughborough South'},
#  {'id': 'NL64', 'name': 'Shepshed Loughborough West'},
#  {'id': 'NL65', 'name': 'Loughborough East'},
#  {'id': 'NN43', 'name': 'Valley'},
#  {'id': 'NN44', 'name': 'Coalville Town'},
#  {'id': 'NN45', 'name': 'Bardon Hill'},
#  {'id': 'NN46', 'name': 'Ashby'},
#  {'id': 'NN47', 'name': 'Forest'},
#  {'id': 'NN48', 'name': 'East Midlands Airport'},
#  {'id': 'NR30', 'name': 'Melton Rural South'},
#  {'id': 'NR31', 'name': 'Melton Town Centre'},
#  {'id': 'NR32', 'name': 'Melton Town North'},
#  {'id': 'NR33', 'name': 'Melton Town South'},
#  {'id': 'NR34', 'name': 'Melton Rural North'},
#  {'id': 'NR35', 'name': 'Oakham Town and Barleythorpe'},
#  {'id': 'NR36', 'name': 'Rutland North'},
#  {'id': 'NR37', 'name': 'Rutland South'},
#  {'id': 'NR38', 'name': 'Uppingham'},
#  {'id': 'NR39', 'name': 'Broughton Astley and Walton'},
#  {'id': 'NR40', 'name': 'Lutterworth'},
#  {'id': 'NR41', 'name': 'Harborough North'},
#  {'id': 'NR42', 'name': 'Harborough and the Bowdens'},
#  {'id': 'NS49', 'name': 'Knighton'},
#  {'id': 'NS50', 'name': 'Freemen/Saffron'},
#  {'id': 'NS51', 'name': 'Eyres Monsell'},
#  {'id': 'NS52', 'name': 'Aylestone'},
#  {'id': 'NS53', 'name': 'South Wigston '},
#  {'id': 'NS54', 'name': 'Wigston'},
#  {'id': 'NS55', 'name': 'Oadby'},
#  {'id': 'NW01', 'name': 'Western'},
#  {'id': 'NW02', 'name': 'Abbey'},
#  {'id': 'NW03', 'name': 'Beaumont Leys'},
#  {'id': 'NW05', 'name': 'Braunstone Park and Rowley Fields'},
#  {'id': 'NW06', 'name': 'Fosse'},
#  {'id': 'NW08', 'name': 'Westcotes'}]

# %%
def extract_specific_neighbourhoods_for_a_force(force: str = 'leicestershire', neighbourhood_id: str = 'NC04'):
    base_url = 'https://data.police.uk/api/'

    if (force != None) and (neighbourhood_id != None):
        url = base_url + f"{force}/{neighbourhood_id}"
    elif (force == None) and (neighbourhood_id == None):
        return f'specify the neighbourhood_id and force'
    else:
        raise ValueError(f"Specify the force and neighbourhood that you passed and make sure it's correct: force={force}, neighbourhood_id={neighbourhood_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_specific_neighbourhoods_for_a_force(force='leicestershire', neighbourhood_id='NC04')
# Out:
# {'url_force': 'http://www.leics.police.uk/local-policing/city-centre',
#  'contact_details': {},
#  'name': 'City Centre',
#  'links': [{'url': 'http://www.leicester.gov.uk/',
#    'description': None,
#    'title': 'Leicester City Council'}],
#  'centre': {'latitude': '52.6389', 'longitude': '-1.13619'},
#  'locations': [],
#  'description': "<p>The Castle neighbourhood\xa0is\xa0a diverse\xa0covering all of the City Centre. In addition it covers De Montfort University, the University of Leicester,\xa0Leicester Royal Infirmary, the Leicester Tigers rugby ground and\xa0the Clarendon Park and Riverside communities.</p>\n<p>The Highcross and Haymarket shopping centres\xa0and Leicester's famous Market are all covered by\xa0this neighbourhood.</p>",
#  'id': 'NC04',
#  'population': '0'}

# %%
def extract_neighbourhood_boundary_for_a_force(force: str = 'leicestershire', neighbourhood_id: str = 'NC04'):
    base_url = 'https://data.police.uk/api/'

    if (force != None) and (neighbourhood_id != None):
        url = base_url + f"{force}/{neighbourhood_id}/boundary"
    elif (force == None) and (neighbourhood_id == None):
        return f'specify the neighbourhood_id and force'
    else:
        raise ValueError(f"Specify the force and neighbourhood that you passed and make sure it's correct: force={force}, neighbourhood_id={neighbourhood_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbour
#  {'latitude': '52.6433310907', 'longitude': '-1.1276793916'},
#  {'latitude': '52.6446848996', 'longitude': '-1.126520776'},
#  {'latitude': '52.6448174552', 'longitude': '-1.1269897771'},
#  {'latitude': '52.6449645475', 'longitude': '-1.1271625904'},
#  {'latitude': '52.6450754906', 'longitude': '-1.1271999963'},
#  {'latitude': '52.6452169632', 'longitude': '-1.1271714663'},
#  {'latitude': '52.6452961141', 'longitude': '-1.1271279166'},
#  {'latitude': '52.6453605138', 'longitude': '-1.1270101665'},
#  {'latitude': '52.6454623178', 'longitude': '-1.1269298059'},
#  {'latitude': '52.6456370795', 'longitude': '-1.1272096737'},
#  {'latitude': '52.6458549308', 'longitude': '-1.1276764012'},
#  {'latitude': '52.6461459267', 'longitude': '-1.1282364251'},
#  {'latitude': '52.6461450398', 'longitude': '-1.1282380686'},
#  {'latitude': '52.6461787756', 'longitude': '-1.1283022861'},
#  {'latitude': '52.6461387484', 'longitude': '-1.1282260733'},
#  {'latitude': '52.6454895298', 'longitude': '-1.129527082'},
#  {'latitude': '52.6451239511', 'longitude': '-1.1305244654'},
#  {'latitude': '52.6444408763', 'longitude': '-1.1312453679'},
#  {'latitude': '52.644213906', 'longitude': '-1.1315800446'},
#  {'latitude': '52.6438173084', 'longitude': '-1.1322479589'},
#  {'latitude': '52.6434807264', 'longitude': '-1.1332918564'},
#  {'latitude': '52.643315581', 'longitude': '-1.1342382113'},
#  {'latitude': '52.6434261394', 'longitude': '-1.1336702616'},
#  {'latitude': '52.643316615', 'longitude': '-1.134379633'},
#  {'latitude': '52.6432326615', 'longitude': '-1.1346643194'},
#  {'latitude': '52.6432067431', 'longitude': '-1.1350420035'},
#  {'latitude': '52.6432378273', 'longitude': '-1.1353714138'},
#  {'latitude': '52.6430967766', 'longitude': '-1.1357042122'},
#  {'latitude': '52.6430132527', 'longitude': '-1.1360358766'},
#  {'latitude': '52.6427858343', 'longitude': '-1.1363232238'},
#  {'latitude': '52.6427067768', 'longitude': '-1.1372678355'},
#  {'latitude': '52.6425104327', 'longitude': '-1.1378845802'},
#  {'latitude': '52.6422561423', 'longitude': '-1.1384083135'},
#  {'latitude': '52.6420332645', 'longitude': '-1.1393084346'},
#  {'latitude': '52.6417520028', 'longitude': '-1.14006841'},
#  {'latitude': '52.6415867104', 'longitude': '-1.1410145343'},
#  {'latitude': '52.6413644939', 'longitude': '-1.142009057'},
#  {'latitude': '52.6410278221', 'longitude': '-1.14305295'},
#  {'latitude': '52.6407765711', 'longitude': '-1.1440007264'},
#  {'latitude': '52.6398933322', 'longitude': '-1.1458367178'},
#  {'latitude': '52.6394052587', 'longitude': '-1.1458618876'}]

# %%
def extract_neighbourhood_team_for_a_force(force: str = 'leicestershire', neighbourhood_id: str = 'NC04'):
    base_url = 'https://data.police.uk/api/'

    if (force != None) and (neighbourhood_id != None):
        url = base_url + f"{force}/{neighbourhood_id}/people"
    elif (force == None) and (neighbourhood_id == None):
        return f'specify the neighbourhood_id and force'
    else:
        raise ValueError(f"Specify the force and neighbourhood that you passed and make sure it's correct: force={force}, neighbourhood_id={neighbourhood_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbourhood_team_for_a_force(force = 'leicestershire', neighbourhood_id = 'NC04')
# Out:
# [{'bio': None,
#   'contact_details': {},
#   'name': 'Zane Tompkins',
#   'rank': 'Sergeant 4081'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Bec Sanders',
#   'rank': 'PCSO 6628'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Donna Green',
#   'rank': 'PCSO 6669'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Jane Elton',
#   'rank': 'PCSO 6040'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Tim Jones',
#   'rank': 'PCSO 6036'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Karl Turner',
#   'rank': 'Police Constable 1467'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Tom Page-Brown',
#   'rank': 'Police Constable 4486'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Jordan Spencer',
#   'rank': 'Police Constable 4611'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Katie Spencer',
#   'rank': 'Police Constable 4416'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Elliot Godden',
#   'rank': 'Police Constable 4323'},
#  {'bio': None,
#   'contact_details': {},
#   'name': 'Ellis Stretton',
#   'rank': 'Police Constable 178'}]

# %%
def extract_neighbourhood_events_for_a_force(force: str = 'leicestershire', neighbourhood_id: str = 'NC04'):
    base_url = 'https://data.police.uk/api/'

    if (force != None) and (neighbourhood_id != None):
        url = base_url + f"{force}/{neighbourhood_id}/events"
    elif (force == None) and (neighbourhood_id == None):
        return f'specify the neighbourhood_id and force'
    else:
        raise ValueError(f"Specify the force and neighbourhood that you passed and make sure it's correct: force={force}, neighbourhood_id={neighbourhood_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbourhood_events_for_a_force(force = 'leicestershire', neighbourhood_id = 'NC04')
# Out:
# [{'contact_details': {},
#   'description': '<p>PCSO Jane Elton and PC Tom Page-Brown, will be at the Abbey park Campus, registering students and staffs bikes to the bike register. This is a completely free service, Dr Bike will also be there to fix any minor issues with your bike.</p>',
#   'end_date': '2024-05-14T14:00:00',
#   'title': 'Dr Bike, Bike Register Event, Abbey Park Campus',
#   'address': 'Abbey Park Campus, Leicester ',
#   'type': 'other',
#   'start_date': '2024-05-14T10:00:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Tim Jones will be conducting a series of visits to stores ands chats with visitors about various crime reduction themes including thefts and burglaries</p>',
#   'end_date': '2024-05-16T18:00:00',
#   'title': 'Crime reduction drop-in, Haymarket Shopping Centre',
#   'address': 'Haymarket Shopping Centre, Leicester',
#   'type': 'other',
#   'start_date': '2024-05-16T16:30:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Donna Green, will be at the Blood Donor Centre to speak to donors and staff members about crime prevention and the steps you can take to help you safe while out and about.</p>',
#   'end_date': '2024-05-20T14:00:00',
#   'title': 'Crime Prevention Advice, Blood Donor Centre',
#   'address': 'Blood Donor Centre, Guildhall Lane, Leicester',
#   'type': 'other',
#   'start_date': '2024-05-20T13:00:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Tim Jones will be conducting a series of visits to stores ands chats with visitors about various crime reduction themes including thefts and burglaries</p>',
#   'end_date': '2024-05-22T11:30:00',
#   'title': 'Crime reduction drop-in, Haymarket Shopping Centre',
#   'address': 'Haymarket Shopping Centre, Leicester',
#   'type': 'other',
#   'start_date': '2024-05-22T10:00:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Tim Jones will be conducting a series of visits to stores ands chats with visitors about various crime reduction themes including thefts and burglaries</p>',
#   'end_date': '2024-06-10T11:00:00',
#   'title': 'Crime reduction drop-in, Haymarket Shopping Centre',
#   'address': 'Haymarket Shopping Centre, Leicester',
#   'type': 'other',
#   'start_date': '2024-06-10T09:30:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Jane Elton, will be at the Library to talk to members of the public about crime reduction.</p>',
#   'end_date': '2024-06-26T13:00:00',
#   'title': 'Monthly library drop-in session',
#   'address': 'Bishop Street, Leicester Central Library ',
#   'type': 'other',
#   'start_date': '2024-06-26T11:00:00'},
#  {'contact_details': {},
#   'description': '<p>PCSO Tim Jones will be conducting a series of visits to stores ands chats with visitors about various crime reduction themes including thefts and burglaries</p>',
#   'end_date': '2024-07-10T17:30:00',
#   'title': 'Crime reduction drop-in, Haymarket Shopping Centre',
#   'address': 'Haymarket Shopping Centre, Leicester',
#   'type': 'other',
#   'start_date': '2024-07-10T16:00:00'}]

# %%
def extract_neighbourhood_priorities_for_a_force(force: str = 'leicestershire', neighbourhood_id: str = 'NC04'):
    base_url = 'https://data.police.uk/api/'

    if (force != None) and (neighbourhood_id != None):
        url = base_url + f"{force}/{neighbourhood_id}/priorities"
    elif (force == None) and (neighbourhood_id == None):
        return f'specify the neighbourhood_id and force'
    else:
        raise ValueError(f"Specify the force and neighbourhood that you passed and make sure it's correct: force={force}, neighbourhood_id={neighbourhood_id}")
    
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbourhood_priorities_for_a_force(force = 'leicestershire', neighbourhood_id = 'NC04')
# Out:
# [{'action': '<p>*APRIL UPDATE*<br />WE DID:<br />Joint patrols conducted with Highcross security focusing on shop theft and anti-social behaviour.<br />Visits to Vision Express and Cotswold Outdoor to offer tailored advice to management on the topic of shop theft.<br />A male suspect identified for burglary at the Highcross has been arrested, charged and remanded.<br />A male suspect trying to sell stolen items in the City Centre was caught in the act by the beat team. The items have been returned to the owner and the male has been processed for the offence via an out of court disposal.<br />A prolific shop thief has been issued with a CBO banning him from various locations in the city centre after being charged with multiple theft offences.<br />Our PCSO’s have held various engagements across the city centre focusing on the subject of crime prevention, including theft. Please check our website for our upcoming events.</p>',
#   'issue-date': '2024-04-01T00:00:00',
#   'action-date': '2024-05-01T00:00:00',
#   'issue': '<p>Retail Crime – focused around the Haymarket and Highcross Shopping Centres.</p>\n\n<p>YOU SAID: There have been issues around shop theft within these areas which has caused you concern.</p>'},
#  {'action': '<p>*APRIL UPDATE*<br />WE DID:<br />A second male has been issued a CBO banning him from various locations within the city centre after being charged for public order and drugs offences. <br />Regular high visibility foot patrol of the area has been conducted by the beat team to prevent and deter activity. <br />A male subject to a stop search after acting suspiciously was found in possession of a small amount of Cannabis. He has been issued with an out of court disposal and given positive requirements to engage with support services.<br />PC Karl has been out with support services to engage with the street lifestyle community and help  support with their needs.<br />PC Elliot has located a suspect male dealing drugs within the City Centre. The male was arrested and found in possessions of drugs and cash which have been seized. The investigation is ongoing.</p>',
#   'issue-date': '2024-04-01T00:00:00',
#   'action-date': '2024-05-01T00:00:00',
#   'issue': '<p>Drug use and drug related ASB around the Angel Gateway and the Market Place.</p>\n\n<p>YOU SAID: There has been an increase in drug related issues around this location which has caused alarm and distress to the community.</p>'},
#  {'action': '<p>*APRIL UPDATE*<br />WE DID:<br />PCSO Donna has conducted a site visit with Wardens at Abbey Campus to discuss the issues and work towards reducing them.<br />PC’s Tom and Jordan also seized a vehicle from this location for no insurance after the occupant caught their eye for acting in an anti-social manner.<br />2 community resolutions have been issued to youths that have been causing ASB at The Arches residential building, one of conditions was to write a letter of apology for their actions. <br />After reports of ASB on the KEEPMOAT building site, SOAR LANE the beat team are working with staff there to identify those responsible. So far 2 have been identified and the ASB incremental approach has been started via warning letter. <br />The beat team have increased their patrol of this part of the beat both on foot and in vehicles.</p>',
#   'issue-date': '2024-04-01T00:00:00',
#   'action-date': '2024-05-01T00:00:00',
#   'issue': '<p>Anti-Social Behavior around Abbey Campus, Memory Lane and the industrial estate.</p>\n\n<p>YOU SAID: There has been an increase in ASB in this area and have reported these matters to us.</p>'}]

# %%
def extract_neighbourhood_at_location(lat: float, lng: float):
    base_url = 'https://data.police.uk/api/locate-neighbourhood?'

    if (lat != None) and (lng != None):
        url = base_url + f"q={lat},{lng}"
    else:
        return f'specify the lat and lng'
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)

    return list_of_dict

# %%
extract_neighbourhood_at_location(lat=51.500617, lng=-0.124629)
# Out:
# {'force': 'metropolitan', 'neighbourhood': 'E05013806N'}

# %% [markdown]
# # Stop and Search

# %%
def extract_stop_search(date: str = None, lng: float = None, lat: float = None, poly: list = None, location_id: str = None):
    """
    Params:
    lat - Latitude of the requested crime area
    lng - Longitude of the requested crime area
    date - Optional. "YYYY-MM" Limit results to a specific month. 
        The latest month will be shown by default
    poly - The lat/lng pairs which define the boundary of the custom area. 
        The poly parameter is formatted in lat/lng pairs, separated by 
        colons: [lat],[lng]:[lat],[lng]:[lat],[lng]
    location_id - The ID of the location to get stop and searches for
    """

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month
    if location_id != None:
        base_url = "http://data.police.uk/api/stops-at-location?"
    else: 
        base_url = 'https://data.police.uk/api/stops-street?'

    if date == None:
        if lat and lng != None:
            url = base_url + f"lat={lat}&lng={lng}&date={current_year}-{current_month}"
        elif poly != None:
            url = base_url + f"poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]},{poly[2][1]}&date={current_year}-{current_month}"
        elif location_id!= None:
            url = base_url + f"location_id={location_id}&date={current_year}-{current_month}"
        else:
            raise ValueError(f'Specify the lat/lang or poly that you passed or make sure they are correct: lat/lang-{lat, lng}, poly={poly}')
    
    elif date != None:
        if lat and lng != None:
            url = base_url + f"lat={lat}&lng={lng}&date={date}"
        elif poly != None:
            url = base_url + f"poly={poly[0][0]}:{poly[0][1]},{poly[1][0]}:{poly[1][1]},{poly[2][0]}:{poly[2][1]}&date={date}"
        elif location_id!= None:
            url = base_url + f"location_id={location_id}&date={date}"
        else:
            raise ValueError(f'Specify the lat/lang or poly that you passed or make sure they are correct: lat/lang-{lat, lng}, poly={poly}')
        
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_stop_search(date = '2023-04', lat = 51.56768064709022, lng = -0.19088745117187503)
# Out:
# [{'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Firearms Act 1968 (section 47)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-09T23:57:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.559283',
#    'street': {'id': 1671125, 'name': 'On or near Windmill Hill'},
#    'longitude': '-0.180776'},
#   'operation': False,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Firearms'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T01:35:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.556496',
#    'street': {'id': 1669667, 'name': 'On or near Heath Drive'},
#    'longitude': '-0.190134'},
#   'operation': False,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-07T02:17:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.567968',
#    'street': {'id': 1669035, 'name': 'On or near Fernside'},
#    'longitude': '-0.194671'},
#   'operation': False,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-10T03:30:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.573887',
#    'street': {'id': 1667833, 'name': 'On or near Gainsborough Gardens'},
#    'longitude': '-0.204134'},
#   'operation': False,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T08:24:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.578001',
#    'street': {'id': 1667521, 'name': 'On or near Flower Mews'},
#    'longitude': '-0.206801'},
#   'operation': False,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-27T16:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.570746',
#    'street': {'id': 1669161, 'name': 'On or near Supermarket'},
#    'longitude': '-0.194552'},
#   'operation': False,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'}]

# %%
def extract_stop_search_noloc(date: str, force: str = None):
    """
    Parameters:
    date - Optional. "YYYY-MM" Limit results to a specific month.
    The latest month will be shown by default
    force - the name of the forces
    """

    base_url = 'https://data.police.uk/api/stops-no-location?'

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    if date == None:
        if force != None:
            url = base_url + f"force={force}&date={current_year}-{current_month}"
        else:
            raise ValueError(f'Specify the name of the force parameter')
    
    elif date != None:
        if force != None:
            url = base_url + f"force={force}&date={date}"
        else:
            raise ValueError(f'Specify the name of the force parameter')
        
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_stop_search_noloc(date='2023-02', force='cleveland')
# Out:
# [{'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-02-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-10T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-12T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-12T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-13T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-14T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-02-15T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-15T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-15T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Articles for use in criminal damage'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-19T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-19T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': '',
#   'involved_person': False,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-21T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-24T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-02-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Articles for use in criminal damage'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-02-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-02-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': None,
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-02-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'}]

# %%
def extract_stop_search_force(date: str = None, force: str = 'avon-and-somerset'):
    """
    Parameters:
    date - Optional. "YYYY-MM" Limit results to a specific month.
    The latest month will be shown by default
    force - the name of the forces
    """

    base_url = 'https://data.police.uk/api/stops-force?'

    # Get current year
    current_year = datetime.now().year

    # Get current month
    current_month = datetime.now().month

    if date == None:
        if force != None:
            url = base_url + f"force={force}&date={current_year}-{current_month}"
        else:
            raise ValueError(f'Specify the name of the force parameter')
    
    elif date != None:
        if force != None:
            url = base_url + f"force={force}&date={date}"
        else:
            raise ValueError(f'Specify the name of the force parameter')
        
    else: 
        raise ValueError(f'Specify the date, you passed {date}')
   
   
    r = requests.get(url)
    list_of_dict = json.loads(r.content)
    
    return list_of_dict

# %%
extract_stop_search_force(date='2023-04', force='avon-and-somerset')
# Out:
# [{'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.392086',
#    'street': {'id': 2288310, 'name': 'On or near Cavendish Crescent'},
#    'longitude': '-2.369735'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '51.529530',
#    'street': {'id': 2287050, 'name': 'On or near Abbotswood'},
#    'longitude': '-2.423133'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Anything to threaten or harm anyone'},
#  {'age_range': 'over 34',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-30T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.425414',
#    'street': {'id': 2279249, 'name': 'On or near Barnstaple Road'},
#    'longitude': '-2.586479'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-20T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.454557',
#    'street': {'id': 2279257, 'name': 'On or near Queen Street'},
#    'longitude': '-2.586306'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '50.972018',
#    'street': {'id': 2265988, 'name': 'On or near Newton Lane'},
#    'longitude': '-3.095843'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-12T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '50.942528',
#    'street': {'id': 2276592, 'name': 'On or near Parking Area'},
#    'longitude': '-2.628674'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.275577',
#    'street': {'id': 2272580, 'name': 'On or near Bath Street'},
#    'longitude': '-2.777446'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.126518',
#    'street': {'id': 2267176, 'name': "On or near St Saviour'S Avenue"},
#    'longitude': '-3.001666'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-09T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.431064',
#    'street': {'id': 2280330, 'name': 'On or near Crossway Mews'},
#    'longitude': '-2.569535'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.476047',
#    'street': {'id': 2280596, 'name': 'On or near Woburn Road'},
#    'longitude': '-2.564292'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.494353',
#    'street': {'id': 2280060, 'name': 'On or near Rose Mead'},
#    'longitude': '-2.573838'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.494509',
#    'street': {'id': 2280213, 'name': 'On or near Melton Crescent'},
#    'longitude': '-2.571247'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Asian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-19T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.458520',
#    'street': {'id': 2277703, 'name': 'On or near Theatre/Concert Hall'},
#    'longitude': '-2.609717'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-06T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.525605',
#    'street': {'id': 2278624, 'name': 'On or near Shopping Area'},
#    'longitude': '-2.595396'},
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-08T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.403344',
#    'street': {'id': 2278850, 'name': 'On or near Barbour Road'},
#    'longitude': '-2.592839'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-08T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.403344',
#    'street': {'id': 2278850, 'name': 'On or near Barbour Road'},
#    'longitude': '-2.592839'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': None},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.456703',
#    'street': {'id': 2279335, 'name': 'On or near Parking Area'},
#    'longitude': '-2.585081'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-13T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.495249',
#    'street': {'id': 2275056, 'name': 'On or near Humberstan Walk'},
#    'longitude': '-2.674035'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.129333',
#    'street': {'id': 2273903, 'name': 'On or near Wessex Close'},
#    'longitude': '-2.735216'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.457581',
#    'street': {'id': 2279759, 'name': "On or near Bragg'S Lane"},
#    'longitude': '-2.578601'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.346738',
#    'street': {'id': 2268377, 'name': 'On or near Swiss Court'},
#    'longitude': '-2.970493'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'Summons / charged by post',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-19T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-summons', 'name': 'Summons / charged by post'},
#   'location': {'latitude': '51.464084',
#    'street': {'id': 2278932, 'name': 'On or near Nine Tree Hill'},
#    'longitude': '-2.590833'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-28T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-08T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.492193',
#    'street': {'id': 2277362, 'name': 'On or near Albert Place'},
#    'longitude': '-2.615078'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.222678',
#    'street': {'id': 2267788, 'name': 'On or near Tregelles Close'},
#    'longitude': '-2.982874'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.222678',
#    'street': {'id': 2267788, 'name': 'On or near Tregelles Close'},
#    'longitude': '-2.982874'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'under 10',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Firearms Act 1968 (section 47)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-10T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.406587',
#    'street': {'id': 2278416, 'name': 'On or near Petrol Station'},
#    'longitude': '-2.598689'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Firearms'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-21T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.463861',
#    'street': {'id': 2278888, 'name': 'On or near Thomas Street North'},
#    'longitude': '-2.592212'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-28T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Firearms Act 1968 (section 47)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.413063',
#    'street': {'id': 2281241, 'name': 'On or near Tibbott Road'},
#    'longitude': '-2.554458'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.222678',
#    'street': {'id': 2267788, 'name': 'On or near Tregelles Close'},
#    'longitude': '-2.982874'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.351560',
#    'street': {'id': 2267931, 'name': 'On or near Parking Area'},
#    'longitude': '-2.979943'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': None,
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-30T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.538699',
#    'street': {'id': 2287278, 'name': 'On or near Supermarket'},
#    'longitude': '-2.414431'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-28T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-19T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.459290',
#    'street': {'id': 2279828, 'name': 'On or near Harleston Street'},
#    'longitude': '-2.576637'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-18T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.129742',
#    'street': {'id': 2266883, 'name': 'On or near Victoria Road'},
#    'longitude': '-3.012583'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-20T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.425406',
#    'street': {'id': 2278414, 'name': 'On or near Novers Road'},
#    'longitude': '-2.598734'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.446085',
#    'street': {'id': 2279108, 'name': 'On or near Mede Close'},
#    'longitude': '-2.588615'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.525605',
#    'street': {'id': 2278624, 'name': 'On or near Shopping Area'},
#    'longitude': '-2.595396'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '51.525605',
#    'street': {'id': 2278624, 'name': 'On or near Shopping Area'},
#    'longitude': '-2.595396'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-01T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.462846',
#    'street': {'id': 2279005, 'name': 'On or near Thomas Street'},
#    'longitude': '-2.590141'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.350722',
#    'street': {'id': 2267924, 'name': 'On or near Wadham Street'},
#    'longitude': '-2.980141'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-28T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.461821',
#    'street': {'id': 2279349, 'name': 'On or near Bishop Street'},
#    'longitude': '-2.584729'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-01T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.462846',
#    'street': {'id': 2279005, 'name': 'On or near Thomas Street'},
#    'longitude': '-2.590141'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.413799',
#    'street': {'id': 2284570, 'name': 'On or near Parking Area'},
#    'longitude': '-2.496691'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.473052',
#    'street': {'id': 2281229, 'name': 'On or near Gloster Avenue'},
#    'longitude': '-2.553169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-18T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '51.015589',
#    'street': {'id': 2266128, 'name': 'On or near Grays Road'},
#    'longitude': '-3.088858'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': None,
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-13T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.969921',
#    'street': {'id': 2250952, 'name': 'On or near Emerys Road'},
#    'longitude': '-1.066952'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.473052',
#    'street': {'id': 2281229, 'name': 'On or near Gloster Avenue'},
#    'longitude': '-2.553169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.473052',
#    'street': {'id': 2281229, 'name': 'On or near Gloster Avenue'},
#    'longitude': '-2.553169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-06T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.459436',
#    'street': {'id': 2281238, 'name': 'On or near Church Road'},
#    'longitude': '-2.553810'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-27T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.378144',
#    'street': {'id': 2288548, 'name': 'On or near Southgate Street'},
#    'longitude': '-2.359780'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.372050',
#    'street': {'id': 2287734, 'name': 'On or near Supermarket'},
#    'longitude': '-2.396321'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.471261',
#    'street': {'id': 2280600, 'name': 'On or near Napier Road'},
#    'longitude': '-2.564795'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.458707',
#    'street': {'id': 2279807, 'name': 'On or near Lawfords Gate'},
#    'longitude': '-2.578169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.458707',
#    'street': {'id': 2279807, 'name': 'On or near Lawfords Gate'},
#    'longitude': '-2.578169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.372050',
#    'street': {'id': 2287734, 'name': 'On or near Supermarket'},
#    'longitude': '-2.396321'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-11T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.458707',
#    'street': {'id': 2279807, 'name': 'On or near Lawfords Gate'},
#    'longitude': '-2.578169'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-01T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.381429',
#    'street': {'id': 2288487, 'name': 'On or near Westgate Street'},
#    'longitude': '-2.361617'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-07T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.405546',
#    'street': {'id': 2277043, 'name': 'On or near Pesley Close'},
#    'longitude': '-2.619047'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.525064',
#    'street': {'id': 2278198, 'name': 'On or near Shopping Area'},
#    'longitude': '-2.601640'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.509198',
#    'street': {'id': 2280650, 'name': 'On or near Ventnor Road'},
#    'longitude': '-2.564544'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
# ...
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-30T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.348776',
#    'street': {'id': 2268063, 'name': 'On or near Palmer Street'},
#    'longitude': '-2.977271'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Khat or Cannabis warning',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-khat-or-cannabis-warning',
#    'name': 'Khat or Cannabis warning'},
#   'location': {'latitude': '51.467733',
#    'street': {'id': 2285741, 'name': 'On or near Siston Hill'},
#    'longitude': '-2.472112'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': None,
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-03T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': None,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': None,
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': None},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-25T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.493059',
#    'street': {'id': 2279098, 'name': 'On or near Tilling Road'},
#    'longitude': '-2.588140'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.235926',
#    'street': {'id': 2267327, 'name': 'On or near High Street'},
#    'longitude': '-2.997495'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.142443',
#    'street': {'id': 2273898, 'name': 'On or near Beckery New Road'},
#    'longitude': '-2.732537'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-30T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.348776',
#    'street': {'id': 2268063, 'name': 'On or near Palmer Street'},
#    'longitude': '-2.977271'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.467733',
#    'street': {'id': 2285741, 'name': 'On or near Siston Hill'},
#    'longitude': '-2.472112'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Irish',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-14T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.184861',
#    'street': {'id': 2283193, 'name': 'On or near Doulting Hill'},
#    'longitude': '-2.516474'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-14T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '51.333498',
#    'street': {'id': 2268597, 'name': 'On or near Windermere Avenue'},
#    'longitude': '-2.963266'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.142443',
#    'street': {'id': 2273898, 'name': 'On or near Beckery New Road'},
#    'longitude': '-2.732537'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Asian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-10T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.453161',
#    'street': {'id': 2278265, 'name': 'On or near Unity Street'},
#    'longitude': '-2.600924'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.467733',
#    'street': {'id': 2285741, 'name': 'On or near Siston Hill'},
#    'longitude': '-2.472112'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-22T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.467733',
#    'street': {'id': 2285741, 'name': 'On or near Siston Hill'},
#    'longitude': '-2.472112'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'under 10',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.558206',
#    'street': {'id': 2280592, 'name': 'On or near The Quarries'},
#    'longitude': '-2.563592'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': None},
#  {'age_range': 'under 10',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': None,
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-16T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.558206',
#    'street': {'id': 2280592, 'name': 'On or near The Quarries'},
#    'longitude': '-2.563592'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Mixed',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': None},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-04T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.472074',
#    'street': {'id': 2280989, 'name': 'On or near Freeland Buildings'},
#    'longitude': '-2.558427'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-01T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.128503',
#    'street': {'id': 2267136, 'name': 'On or near Fore Street'},
#    'longitude': '-3.002952'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Evidence of offences under the Act'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': None,
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-02T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.470657',
#    'street': {'id': 2280700, 'name': 'On or near Bourne Lane'},
#    'longitude': '-2.563362'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-26T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '51.379682',
#    'street': {'id': 2288632, 'name': 'On or near Parking Area'},
#    'longitude': '-2.356617'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Psychoactive Substances Act 2016 (s36(2))',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.462667',
#    'street': {'id': 2279039, 'name': 'On or near Stokes Croft'},
#    'longitude': '-2.590023'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Psychoactive substances'},
#  {'age_range': 'under 10',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': None,
#   'legislation': 'Psychoactive Substances Act 2016 (s36(2))',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2023-04-23T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '51.462667',
#    'street': {'id': 2279039, 'name': 'On or near Stokes Croft'},
#    'longitude': '-2.590023'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Psychoactive substances'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2023-04-09T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': None,
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'}]
